# %% [markdown]
# # **Importing libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# # **Reading films Dataset**

# %%
films = pd.read_excel('D:\\Data Analytics for Business\\DAB 103\\Project\\bollywood_films.xlsx')
films
# Out:
#                              Movie Name Release Period Whether Remake  \
# 0                           Golden Boys         Normal             No
# 1                         Kaccha Limboo        Holiday             No
# 2                      Not A Love Story        Holiday             No
# 3                            Qaidi Band        Holiday             No
# 4                             Chaatwali        Holiday             No
# ...                                 ...            ...            ...
# 1693                         Fight Club        Holiday             No
# 1694                 Strings Of Paasion         Normal             No
# 1695              Dunno Y Na Jaane Kyun         Normal             No
# 1696  Taj Mahal - An Eternal Love Story         Normal             No
# 1697                   Mr. Hot Mr. Kool         Normal             No
#
#      Whether Franchise     Genre New Actor New Director New Music Director  \
# ...

# %%
films.head()
# Out:
#          Movie Name Release Period Whether Remake Whether Franchise     Genre  \
# 0       Golden Boys         Normal             No                No  suspense
# 1     Kaccha Limboo        Holiday             No                No     drama
# 2  Not A Love Story        Holiday             No                No  thriller
# 3        Qaidi Band        Holiday             No                No     drama
# 4         Chaatwali        Holiday             No                No     adult
#
#   New Actor New Director New Music Director         Lead Star  \
# 0       Yes           No                 No      Jeet Goswami
# 1       Yes           No                Yes  Karan Bhanushali
# 2        No           No                 No        Mahie Gill
# 3       Yes           No                 No        Aadar Jain
# 4       Yes          Yes                Yes        Aadil Khan
#
#           Director   Music Director  Number of Screens  Revenue(INR)  \
# ...

# %%
films.tail()
# Out:
#                              Movie Name Release Period Whether Remake  \
# 1693                         Fight Club        Holiday             No
# 1694                 Strings Of Paasion         Normal             No
# 1695              Dunno Y Na Jaane Kyun         Normal             No
# 1696  Taj Mahal - An Eternal Love Story         Normal             No
# 1697                   Mr. Hot Mr. Kool         Normal             No
#
#      Whether Franchise   Genre New Actor New Director New Music Director  \
# 1693                No  action        No          Yes                 No
# 1694                No   drama        No          Yes                Yes
# 1695                No   drama        No           No                 No
# 1696                No   drama        No          Yes                 No
# 1697                No  comedy        No           No                Yes
#
#         Lead Star               Director  Music Director  Number of Screens  \
# ...

# %% [markdown]
# # **Brief Description of films dataset**

# %%
films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1698 entries, 0 to 1697
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Movie Name          1698 non-null   object
#  1   Release Period      1698 non-null   object
#  2   Whether Remake      1698 non-null   object
#  3   Whether Franchise   1698 non-null   object
#  4   Genre               1698 non-null   object
#  5   New Actor           1698 non-null   object
#  6   New Director        1698 non-null   object
#  7   New Music Director  1698 non-null   object
#  8   Lead Star           1698 non-null   object
#  9   Director            1698 non-null   object
#  10  Music Director      1698 non-null   object
#  11  Number of Screens   1698 non-null   int64
#  12  Revenue(INR)        1698 non-null   int64
#  13  Budget(INR)         1698 non-null   int64
# dtypes: int64(3), object(11)
# memory usage: 185.8+ KB

# %%
films.describe()
# Out:
#        Number of Screens  Revenue(INR)   Budget(INR)
# count        1698.000000  1.698000e+03  1.698000e+03
# mean          553.831567  1.501674e+08  2.377287e+08
# std           782.951839  2.434838e+08  6.134398e+08
# min             1.000000  3.250000e+05  7.250000e+03
# 25%            30.000000  1.500000e+07  1.150000e+06
# 50%           200.000000  5.500000e+07  1.240000e+07
# 75%           800.000000  1.900000e+08  1.778325e+08
# max          4600.000000  2.100000e+09  8.016120e+09

# %%
films.dtypes
# Out:
# Movie Name            object
# Release Period        object
# Whether Remake        object
# Whether Franchise     object
# Genre                 object
# New Actor             object
# New Director          object
# New Music Director    object
# Lead Star             object
# Director              object
# Music Director        object
# Number of Screens      int64
# Revenue(INR)           int64
# Budget(INR)            int64
# dtype: object

# %%
print(films.shape)
# Out:
# (1698, 14)

# %%
print(films.columns)
# Out:
# Index(['Movie Name', 'Release Period', 'Whether Remake', 'Whether Franchise',
#        'Genre', 'New Actor', 'New Director', 'New Music Director', 'Lead Star',
#        'Director', 'Music Director', 'Number of Screens', 'Revenue(INR)',
#        'Budget(INR)'],
#       dtype='object')

# %%
print(films.index)
# Out:
# RangeIndex(start=0, stop=1698, step=1)

# %% [markdown]
# # **To find duplicate values in films**

# %%
films[films.duplicated()]
# Out:
#      Movie Name Release Period Whether Remake Whether Franchise     Genre  \
# 683       Aatma         Normal             No                No    horror
# 1269       Game        Holiday            Yes                No  thriller
#
#      New Actor New Director New Music Director          Lead Star  \
# 683         No           No                 No       Bipasha Basu
# 1269        No          Yes                 No  Abhishek Bachchan
#
#            Director          Music Director  Number of Screens  Revenue(INR)  \
# 683   Deepak Ramsay               Anu Malik                 70      25000000
# 1269    Abhinay Deo  Shankar - Ehsaan - Loy               1100     340000000
#
#       Budget(INR)
# 683       9400000
# 1269    128792500

# %%
films.duplicated().sum()
# Out:
# 2

# %% [markdown]
# # **To check null values in films**

# %%
films.isnull().sum()
# Out:
# Movie Name            0
# Release Period        0
# Whether Remake        0
# Whether Franchise     0
# Genre                 0
# New Actor             0
# New Director          0
# New Music Director    0
# Lead Star             0
# Director              0
# Music Director        0
# Number of Screens     0
# Revenue(INR)          0
# Budget(INR)           0
# dtype: int64

# %% [markdown]
# # **To check unique values in each variable**

# %%
films.nunique().sort_values(ascending = False)
# Out:
# Movie Name            1695
# Budget(INR)           1104
# Director              1048
# Lead Star              764
# Music Director         630
# Revenue(INR)           184
# Number of Screens      147
# Genre                   14
# Release Period           2
# Whether Remake           2
# Whether Franchise        2
# New Actor                2
# New Director             2
# New Music Director       2
# dtype: int64

# %%
px.bar(films.nunique().sort_values(ascending = False), films.nunique().sort_values(ascending = False), labels = {'x':'Number of unique values',
                                                                                                                 'index':'Variable name'},
       title = "Unique values in each column of films")

# %% [markdown]
# # **To find correlation between variables of films**

# %%
films.corr()
# Out:
#                    Number of Screens  Revenue(INR)  Budget(INR)
# Number of Screens           1.000000      0.897765     0.775106
# Revenue(INR)                0.897765      1.000000     0.843446
# Budget(INR)                 0.775106      0.843446     1.000000

# %%
sns.heatmap(films.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # **To find outliers in films**

# %%
px.box(films, x='Number of Screens',title = "Number of Outliers in Number of Screens column of films")

# %%
px.box(films, x='Revenue(INR)',labels = {'Revenue(INR)' : 'Amount of Money Made(INR)'}, title = "Number of Outliers in Revenue(INR) column of films")

# %%
px.box(films, x='Budget(INR)',labels = {'Budget(INR)' : 'Amount of Money Spend(INR)'}, title = "Number of Outliers in Budget(INR) column of films")

# %% [markdown]
# # **Reading rating dataset**

# %%
rating = pd.read_excel('D:\\Data Analytics for Business\\DAB 103\\Project\\IMDb_bollywood.xlsx')
rating
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                     NaN     NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi) -2019.0  109 min            Drama
# 2                             #Homecoming -2021.0   90 min   Drama, Musical
# 3                                 #Yaaram -2019.0  110 min  Comedy, Romance
# 4                       ...And Once Again -2010.0  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga -1988.0      NaN           Action
# 15505                               Zulmi -1999.0  129 min    Action, Drama
# 15506                           Zulmi Raj -2005.0      NaN           Action
# 15507                       Zulmi Shikari -1988.0      NaN           Action
# 15508                        Zulm-O-Sitam -1998.0  130 min    Action, Drama
#
# ...

# %%
rating.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                 NaN     NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi) -2019.0  109 min            Drama
# 2                         #Homecoming -2021.0   90 min   Drama, Musical
# 3                             #Yaaram -2019.0  110 min  Comedy, Romance
# 4                   ...And Once Again -2010.0  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# ...

# %%
rating.tail()
# Out:
#                       Name    Year Duration          Genre  Rating Votes  \
# 15504  Zulm Ko Jala Doonga -1988.0      NaN         Action     4.6    11
# 15505                Zulmi -1999.0  129 min  Action, Drama     4.5   655
# 15506            Zulmi Raj -2005.0      NaN         Action     NaN   NaN
# 15507        Zulmi Shikari -1988.0      NaN         Action     NaN   NaN
# 15508         Zulm-O-Sitam -1998.0  130 min  Action, Drama     6.2    20
#
#             Director           Actor 1         Actor 2        Actor 3
# 15504  Mahendra Shah  Naseeruddin Shah   Sumeet Saigal  Suparna Anand
# 15505     Kuku Kohli      Akshay Kumar  Twinkle Khanna    Aruna Irani
# 15506     Kiran Thej   Sangeeta Tiwari             NaN            NaN
# 15507            NaN               NaN             NaN            NaN
# 15508   K.C. Bokadia        Dharmendra      Jaya Prada    Arjun Sarja

# %% [markdown]
# # **Brief description of rating**

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15508 non-null  object
#  1   Year      14981 non-null  float64
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(2), object(8)
# memory usage: 1.2+ MB

# %%
rating.describe()
# Out:
#                Year       Rating
# count  14981.000000  7919.000000
# mean   -1987.012215     5.841621
# std       25.416689     1.381777
# min    -2022.000000     1.100000
# 25%    -2009.000000     4.900000
# 50%    -1991.000000     6.000000
# 75%    -1968.000000     6.800000
# max    -1913.000000    10.000000

# %%
rating.shape
# Out:
# (15509, 10)

# %%
rating.index
# Out:
# RangeIndex(start=0, stop=15509, step=1)

# %%
rating.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
rating.dtypes
# Out:
# Name         object
# Year        float64
# Duration     object
# Genre        object
# Rating      float64
# Votes        object
# Director     object
# Actor 1      object
# Actor 2      object
# Actor 3      object
# dtype: object

# %% [markdown]
# # **To check null values in rating**

# %%
rating.isna().sum().sort_values(ascending = False)
# Out:
# Duration    8269
# Rating      7590
# Votes       7589
# Actor 3     3144
# Actor 2     2384
# Genre       1877
# Actor 1     1617
# Year         528
# Director     525
# Name           1
# dtype: int64

# %%
px.bar(rating.isna().sum().sort_values(ascending = False), rating.isna().sum().sort_values(ascending = False), labels = {'x':'Number of missing values',
                                                                                                                 'index':'Variable name'},
       title = "Missing values in each column of rating")

# %% [markdown]
# # **To find duplicate values in rating**

# %%
rating[rating.duplicated()]
# Out:
#                             Name    Year Duration     Genre  Rating Votes  \
# 1250   Arab Ka Sona - Abu Kaalia -1979.0      NaN    Action     NaN   NaN
# 1769                     Balidan -1992.0      NaN     Drama     NaN   NaN
# 4723     First Time - Pehli Baar -2009.0      NaN       NaN     NaN   NaN
# 9713                     Musafir     NaN      NaN  Thriller     NaN   NaN
# 13069                    Shivani -2019.0      NaN     Crime     NaN   NaN
# 13308          Slumdog Karodpati -2019.0  118 min  Thriller     NaN   NaN
#
#                   Director      Actor 1       Actor 2     Actor 3
# 1250        Master Bhagwan    Meena Rai    Dara Singh         NaN
# 1769                   NaN          NaN           NaN         NaN
# 4723          Raja Bundela  Zeenat Aman   Nitin Arora  Raj Babbar
# 9713           Shiva Dagar          NaN           NaN         NaN
# 13069  Ugresh Prasad Ujala      Santosh           NaN         NaN
# ...

# %%
rating[rating.duplicated()].shape
# Out:
# (6, 10)

# %% [markdown]
# # **To count unique values in each variable of rating**

# %%
rating.nunique().sort_values(ascending = False)
# Out:
# Name        13837
# Director     5938
# Actor 2      4891
# Actor 3      4820
# Actor 1      4718
# Votes        2034
# Genre         485
# Duration      182
# Year          102
# Rating         84
# dtype: int64

# %%
px.bar(rating.nunique().sort_values(ascending = False), rating.nunique().sort_values(ascending = False), labels = {'x' : 'Number of unique values',
                                                                                                                   'index' : 'Variable Name'},
       title = 'Unique values of each columns in rating')

# %% [markdown]
# # **To determine correlation between variables of rating**

# %%
rating.corr()
# Out:
#             Year    Rating
# Year    1.000000  0.166673
# Rating  0.166673  1.000000

# %%
sns.heatmap(rating.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # **To find outliers in rating**

# %%
px.box(rating, x='Year', title = "Number of Outliers in Year column of rating" )

# %%
px.box(rating, x = "Rating",title = "Number of Outliers in Rating column of rating")

# %% [markdown]
# # **To find segements and groups in films**

# %%
px.scatter(films, x = "Budget(INR)", y = "Revenue(INR)", color = "Revenue(INR)", title = "Films in each group of revenue",
           color_continuous_scale=[(0, "yellow"), (1, "red")])

# %% [markdown]
# # **To find segements and groups in rating**

# %%
px.scatter(rating , x = "Year", y = "Rating", color = "Rating", title = "Films in each group of IMDb ratings", color_continuous_scale=[(0, "yellow"), (1, "red")])

# %% [markdown]
# # **Identifying the imbalance data**

# %%
not_remake_films = films[films['Whether Remake'] == 'No'].shape[0]
remake_films = films[films['Whether Remake'] == 'Yes'].shape[0]
print("Ratio is :- ", not_remake_films, ":" ,remake_films)
px.bar(films['Whether Remake'].value_counts(), films['Whether Remake'].value_counts(), labels = {'x' : 'Number of values',
                                                                                                 'index' : 'Whether Remake'}, 
       title = 'Data of remake is imbalance')
# Out:
# Ratio is :-  1627 : 71

# %%
not_franchise_films = films[films['Whether Franchise'] == 'No'].shape[0]
franchise_films = films[films['Whether Franchise'] == 'Yes'].shape[0]
print("Ratio is :- ", not_franchise_films, ":" ,franchise_films)
px.bar(films['Whether Franchise'].value_counts(), films['Whether Franchise'].value_counts(), labels = {'x' : 'Number of values',
                                                                                                 'index' : 'Whether Franchise'}, 
       title = 'Data of Franchise is imbalance')
# Out:
# Ratio is :-  1616 : 82

# %%
not_new_actor = films[films['New Actor'] == 'No'].shape[0]
new_actor = films[films['New Actor'] == 'Yes'].shape[0]
print("Ratio is :- ", not_new_actor, ":" ,new_actor)
px.bar(films['New Actor'].value_counts(), films['New Actor'].value_counts(), labels = {'x' : 'Number of values',
                                                                                                 'index' : 'New Actor'}, 
       title = 'Data of New Actor is no so imbalance')
# Out:
# Ratio is :-  1243 : 455

# %%
not_new_director = films[films['New Director'] == 'No'].shape[0]
new_director = films[films['New Director'] == 'Yes'].shape[0]
print("Ratio is :- ", not_new_director, ":" ,new_director)
px.bar(films['New Director'].value_counts(), films['New Director'].value_counts(), labels = {'x' : 'Number of values',
                                                                                                 'index' : 'New Director'}, 
       title = 'Data of New Director is balance')
# Out:
# Ratio is :-  882 : 816

# %%
not_new_music_director = films[films['New Music Director'] == 'No'].shape[0]
new_music_director = films[films['New Music Director'] == 'Yes'].shape[0]
print("Ratio is :- ", not_new_music_director, ":" ,new_music_director)
px.bar(films['New Music Director'].value_counts(), films['New Music Director'].value_counts(), labels = {'x' : 'Number of values',
                                                                                                 'index' : 'New Music Director'}, 
       title = 'Data of New Music Director is not so imbalance')
# Out:
# Ratio is :-  1144 : 554

# %%
not_holiday_release = films[films['Release Period'] == 'Normal'].shape[0]
holiday_release = films[films['Release Period'] == 'Holiday'].shape[0]
print("Ratio is :- ", not_holiday_release, ":" ,holiday_release)
px.bar(films['Release Period'].value_counts(), films['Release Period'].value_counts(), labels = {'x' : 'Number of values',
                                                                                                 'index' : 'Release Period'}, 
       title = 'Data of Release Period is not so imbalance')
# Out:
# Ratio is :-  1064 : 634

# %% [markdown]
# # **Inclusion Criteria is Genre**

# %% [markdown]
# # **EDA of action films**

# %%
action_films = films[films["Genre"] == "action"]
action_films
# Out:
#                    Movie Name Release Period Whether Remake Whether Franchise  \
# 8                     Ghajini        Holiday            Yes                No
# 17                    Dhoom 3         Normal             No               Yes
# 38                Chakradhaar         Normal             No                No
# 39                    Players         Normal            Yes                No
# 42                      Drona        Holiday             No                No
# ...                       ...            ...            ...               ...
# 1656             Koyelaanchal        Holiday             No                No
# 1666  Shootout At Lokhandwala         Normal             No                No
# 1670           Rakht Charitra        Holiday             No                No
# 1671                   Naksha         Normal             No                No
# 1693               Fight Club        Holiday             No                No
#
# ...

# %%
action_films.head()
# Out:
#      Movie Name Release Period Whether Remake Whether Franchise   Genre  \
# 8       Ghajini        Holiday            Yes                No  action
# 17      Dhoom 3         Normal             No               Yes  action
# 38  Chakradhaar         Normal             No                No  action
# 39      Players         Normal            Yes                No  action
# 42        Drona        Holiday             No                No  action
#
#    New Actor New Director New Music Director          Lead Star  \
# 8         No          Yes                 No         Aamir Khan
# 17        No           No                 No         Aamir Khan
# 38       Yes          Yes                 No     Abhishek Anand
# 39        No           No                 No  Abhishek Bachchan
# 42        No           No                 No  Abhishek Bachchan
#
#                  Director   Music Director  Number of Screens  Revenue(INR)  \
# ...

# %%
action_films.tail()
# Out:
#                    Movie Name Release Period Whether Remake Whether Franchise  \
# 1656             Koyelaanchal        Holiday             No                No
# 1666  Shootout At Lokhandwala         Normal             No                No
# 1670           Rakht Charitra        Holiday             No                No
# 1671                   Naksha         Normal             No                No
# 1693               Fight Club        Holiday             No                No
#
#        Genre New Actor New Director New Music Director     Lead Star  \
# 1656  action        No           No                Yes  Vinod Khanna
# 1666  action        No           No                Yes  Vivek Oberoi
# 1670  action        No           No                Yes  Vivek Oberoi
# 1671  action        No          Yes                 No  Vivek Oberoi
# 1693  action        No          Yes                 No    Zayed Khan
#
#              Director     Music Director  Number of Screens  Revenue(INR)  \
# ...

# %%
action_films.shape
# Out:
# (127, 14)

# %%
action_films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 127 entries, 8 to 1693
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Movie Name          127 non-null    object
#  1   Release Period      127 non-null    object
#  2   Whether Remake      127 non-null    object
#  3   Whether Franchise   127 non-null    object
#  4   Genre               127 non-null    object
#  5   New Actor           127 non-null    object
#  6   New Director        127 non-null    object
#  7   New Music Director  127 non-null    object
#  8   Lead Star           127 non-null    object
#  9   Director            127 non-null    object
#  10  Music Director      127 non-null    object
#  11  Number of Screens   127 non-null    int64
#  12  Revenue(INR)        127 non-null    int64
#  13  Budget(INR)         127 non-null    int64
# dtypes: int64(3), object(11)
# memory usage: 14.9+ KB

# %%
action_films.describe()
# Out:
#        Number of Screens  Revenue(INR)   Budget(INR)
# count         127.000000  1.270000e+02  1.270000e+02
# mean         1189.433071  3.459587e+08  6.120919e+08
# std          1206.399797  4.055316e+08  1.004063e+09
# min             1.000000  1.000000e+06  1.200000e+04
# 25%            62.500000  2.500000e+07  3.350000e+06
# 50%           775.000000  2.100000e+08  1.436070e+08
# 75%          2175.000000  5.200000e+08  8.349712e+08
# max          4600.000000  2.100000e+09  5.651020e+09

# %%
action_films.isnull().sum()
# Out:
# Movie Name            0
# Release Period        0
# Whether Remake        0
# Whether Franchise     0
# Genre                 0
# New Actor             0
# New Director          0
# New Music Director    0
# Lead Star             0
# Director              0
# Music Director        0
# Number of Screens     0
# Revenue(INR)          0
# Budget(INR)           0
# dtype: int64

# %%
action_films.duplicated().sum()
# Out:
# 0

# %%
action_films.nunique()
# Out:
# Movie Name            127
# Release Period          2
# Whether Remake          2
# Whether Franchise       2
# Genre                   1
# New Actor               2
# New Director            2
# New Music Director      2
# Lead Star              69
# Director              100
# Music Director         78
# Number of Screens      72
# Revenue(INR)           86
# Budget(INR)           120
# dtype: int64

# %%
px.bar(action_films.nunique().sort_values(ascending = False), action_films.nunique().sort_values(ascending = False), labels = {'x' : 'Number of unique values',
                                                                                                                   'index' : 'Variable Name'},
       title = 'Unique values of each columns in action films')

# %%
action_films.index
# Out:
# Int64Index([   8,   17,   38,   39,   42,   44,   99,  103,  105,  107,
#             ...
#             1625, 1630, 1636, 1637, 1638, 1656, 1666, 1670, 1671, 1693],
#            dtype='int64', length=127)

# %%
print(action_films.corr())
# Out:
#                    Number of Screens  Revenue(INR)  Budget(INR)
# Number of Screens           1.000000       0.90350     0.805001
# Revenue(INR)                0.903500       1.00000     0.887460
# Budget(INR)                 0.805001       0.88746     1.000000

# %%
sns.heatmap(action_films.corr())
# Out:
# <AxesSubplot:>

# %%
px.box(action_films, x='Number of Screens', title = "Number of Outliers in Number of Screens column of action films")

# %%
px.box(action_films, x='Revenue(INR)',labels = {'Revenue(INR)' : 'Amount of Money Made(INR)'}, title = "Number of Outliers in Revenue(INR) column of action films")

# %%
px.box(action_films, x='Budget(INR)', labels = {'Budget(INR)' : 'Amount of Money Spend(INR)'},title = "Number of Outliers in Budget(INR) column of action films")

# %% [markdown]
# # **EDA of comedy films**

# %%
comedy_films = films[films["Genre"] == "comedy"]
comedy_films
# Out:
#                         Movie Name Release Period Whether Remake  \
# 5                 Shuttlecock Boys         Normal             No
# 24      Malegaon Me Gadbad Ghotala         Normal             No
# 25    Khota Sikka - Jaat Ke Thaath         Normal             No
# 29           Oye Lucky! Lucky Oye!         Normal             No
# 34         Ek Chalis Ki Last Local         Normal             No
# ...                            ...            ...            ...
# 1662               Gollu Aur Pappu        Holiday             No
# 1664               Sooper Se Ooper         Normal             No
# 1668                   Pyare Mohan        Holiday             No
# 1689        Sharafat Gayi Tel Lene         Normal             No
# 1697              Mr. Hot Mr. Kool         Normal             No
#
#      Whether Franchise   Genre New Actor New Director New Music Director  \
# 5                   No  comedy       Yes          Yes                Yes
# ...

# %%
comedy_films.head()
# Out:
#                       Movie Name Release Period Whether Remake  \
# 5               Shuttlecock Boys         Normal             No
# 24    Malegaon Me Gadbad Ghotala         Normal             No
# 25  Khota Sikka - Jaat Ke Thaath         Normal             No
# 29         Oye Lucky! Lucky Oye!         Normal             No
# 34       Ek Chalis Ki Last Local         Normal             No
#
#    Whether Franchise   Genre New Actor New Director New Music Director  \
# 5                 No  comedy       Yes          Yes                Yes
# 24                No  comedy       Yes          Yes                 No
# 25                No  comedy       Yes          Yes                Yes
# 29                No  comedy        No           No                 No
# 34                No  comedy        No          Yes                 No
#
#         Lead Star          Director     Music Director  Number of Screens  \
# 5   Aakar Kaushik       Hemant Gaba     Avinash Baghel                 10
# ...

# %%
comedy_films.tail()
# Out:
#                   Movie Name Release Period Whether Remake Whether Franchise  \
# 1662         Gollu Aur Pappu        Holiday             No                No
# 1664         Sooper Se Ooper         Normal             No                No
# 1668             Pyare Mohan        Holiday             No                No
# 1689  Sharafat Gayi Tel Lene         Normal             No                No
# 1697        Mr. Hot Mr. Kool         Normal             No                No
#
#        Genre New Actor New Director New Music Director     Lead Star  \
# 1662  comedy        No           No                 No       Vir Das
# 1664  comedy        No          Yes                 No       Vir Das
# 1668  comedy        No           No                 No  Vivek Oberoi
# 1689  comedy        No           No                Yes    Zayed Khan
# 1697  comedy        No           No                Yes   Zulfi Sayed
#
#             Director  Music Director  Number of Screens  Revenue(INR)  \
# ...

# %%
print(comedy_films.shape)
# Out:
# (284, 14)

# %%
print(comedy_films.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 284 entries, 5 to 1697
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Movie Name          284 non-null    object
#  1   Release Period      284 non-null    object
#  2   Whether Remake      284 non-null    object
#  3   Whether Franchise   284 non-null    object
#  4   Genre               284 non-null    object
#  5   New Actor           284 non-null    object
#  6   New Director        284 non-null    object
#  7   New Music Director  284 non-null    object
#  8   Lead Star           284 non-null    object
#  9   Director            284 non-null    object
#  10  Music Director      284 non-null    object
#  11  Number of Screens   284 non-null    int64
#  12  Revenue(INR)        284 non-null    int64
#  13  Budget(INR)         284 non-null    int64
# dtypes: int64(3), object(11)
# memory usage: 33.3+ KB
# None

# %%
print(comedy_films.describe())
# Out:
#        Number of Screens  Revenue(INR)   Budget(INR)
# count         284.000000  2.840000e+02  2.840000e+02
# mean          623.633803  1.527130e+08  2.344314e+08
# std           716.120047  1.910378e+08  4.188564e+08
# min             1.000000  5.000000e+05  3.250000e+04
# 25%           103.750000  3.750000e+07  3.443750e+06
# 50%           375.000000  9.000000e+07  3.925000e+07
# 75%           900.000000  2.000000e+08  2.724188e+08
# max          3650.000000  1.420000e+09  3.110450e+09

# %%
print(comedy_films.isnull().sum())
# Out:
# Movie Name            0
# Release Period        0
# Whether Remake        0
# Whether Franchise     0
# Genre                 0
# New Actor             0
# New Director          0
# New Music Director    0
# Lead Star             0
# Director              0
# Music Director        0
# Number of Screens     0
# Revenue(INR)          0
# Budget(INR)           0
# dtype: int64

# %%
print(comedy_films.duplicated().sum())
# Out:
# 0

# %%
print(comedy_films.nunique())
# Out:
# Movie Name            284
# Release Period          2
# Whether Remake          2
# Whether Franchise       2
# Genre                   1
# New Actor               2
# New Director            2
# New Music Director      2
# Lead Star             149
# Director              205
# Music Director        148
# Number of Screens      95
# Revenue(INR)           88
# Budget(INR)           265
# dtype: int64

# %%
px.bar(comedy_films.nunique().sort_values(ascending = False), comedy_films.nunique().sort_values(ascending = False), labels = {'x' : 'Number of unique values',
                                                                                                                   'index' : 'Variable Name'},
       title = 'Unique values of each columns in comedy films')

# %%
print(comedy_films.corr())
# Out:
#                    Number of Screens  Revenue(INR)  Budget(INR)
# Number of Screens           1.000000      0.929200     0.830895
# Revenue(INR)                0.929200      1.000000     0.875433
# Budget(INR)                 0.830895      0.875433     1.000000

# %%
sns.heatmap(comedy_films.corr())
# Out:
# <AxesSubplot:>

# %%
print(comedy_films.index)
# Out:
# Int64Index([   5,   24,   25,   29,   34,   48,   66,   78,   81,   83,
#             ...
#             1646, 1648, 1649, 1650, 1651, 1662, 1664, 1668, 1689, 1697],
#            dtype='int64', length=284)

# %%
px.box(comedy_films, x='Number of Screens', title = "Number of Outliers in Number of Screens column of comedy films")

# %%
px.box(comedy_films, x='Revenue(INR)',labels = {'Revenue(INR)' : 'Amount of Money Made(INR)'}, title = "Number of Outliers in Revenue(INR) column of comedy films")

# %%
px.box(comedy_films, x='Budget(INR)', labels = {'Budget(INR)' : 'Amount of Money Spend(INR)'},title = "Number of Outliers in Budget(INR) column of comedy films")

# %% [markdown]
# # **EDA of drama films**

# %%
drama_films = films[films["Genre"] == "drama"]
drama_films
# Out:
#                              Movie Name Release Period Whether Remake  \
# 1                         Kaccha Limboo        Holiday             No
# 3                            Qaidi Band        Holiday             No
# 7               Future To Bright Hai Ji        Holiday             No
# 9                      Taare Zameen Par        Holiday             No
# 10           Mangal Pandey - The Rising        Holiday             No
# ...                                 ...            ...            ...
# 1686                Satrangee Parachute        Holiday             No
# 1691                              Rocky         Normal             No
# 1694                 Strings Of Paasion         Normal             No
# 1695              Dunno Y Na Jaane Kyun         Normal             No
# 1696  Taj Mahal - An Eternal Love Story         Normal             No
#
#      Whether Franchise  Genre New Actor New Director New Music Director  \
# ...

# %%
drama_films.head()
# Out:
#                     Movie Name Release Period Whether Remake  \
# 1                Kaccha Limboo        Holiday             No
# 3                   Qaidi Band        Holiday             No
# 7      Future To Bright Hai Ji        Holiday             No
# 9             Taare Zameen Par        Holiday             No
# 10  Mangal Pandey - The Rising        Holiday             No
#
#    Whether Franchise  Genre New Actor New Director New Music Director  \
# 1                 No  drama       Yes           No                Yes
# 3                 No  drama       Yes           No                 No
# 7                 No  drama        No          Yes                Yes
# 9                 No  drama        No          Yes                 No
# 10                No  drama        No           No                 No
#
#            Lead Star       Director          Music Director  \
# 1   Karan Bhanushali  Sagar Ballary         Amardeep Nijjer
# ...

# %%
drama_films.tail()
# Out:
#                              Movie Name Release Period Whether Remake  \
# 1686                Satrangee Parachute        Holiday             No
# 1691                              Rocky         Normal             No
# 1694                 Strings Of Paasion         Normal             No
# 1695              Dunno Y Na Jaane Kyun         Normal             No
# 1696  Taj Mahal - An Eternal Love Story         Normal             No
#
#      Whether Franchise  Genre New Actor New Director New Music Director  \
# 1686                No  drama        No          Yes                 No
# 1691                No  drama        No           No                 No
# 1694                No  drama        No          Yes                Yes
# 1695                No  drama        No           No                 No
# 1696                No  drama        No          Yes                 No
#
#           Lead Star               Director     Music Director  \
# ...

# %%
drama_films.shape
# Out:
# (639, 14)

# %%
drama_films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 639 entries, 1 to 1696
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Movie Name          639 non-null    object
#  1   Release Period      639 non-null    object
#  2   Whether Remake      639 non-null    object
#  3   Whether Franchise   639 non-null    object
#  4   Genre               639 non-null    object
#  5   New Actor           639 non-null    object
#  6   New Director        639 non-null    object
#  7   New Music Director  639 non-null    object
#  8   Lead Star           639 non-null    object
#  9   Director            639 non-null    object
#  10  Music Director      639 non-null    object
#  11  Number of Screens   639 non-null    int64
#  12  Revenue(INR)        639 non-null    int64
#  13  Budget(INR)         639 non-null    int64
# dtypes: int64(3), object(11)
# memory usage: 74.9+ KB

# %%
drama_films.describe()
# Out:
#        Number of Screens  Revenue(INR)   Budget(INR)
# count         639.000000  6.390000e+02  6.390000e+02
# mean          369.769953  1.102928e+08  1.642288e+08
# std           618.755654  2.064602e+08  5.293551e+08
# min             1.000000  3.250000e+05  7.250000e+03
# 25%            20.000000  1.000000e+07  5.750000e+05
# 50%            90.000000  3.000000e+07  4.550000e+06
# 75%           450.000000  1.100000e+08  8.155000e+07
# max          4400.000000  1.800000e+09  7.024750e+09

# %%
drama_films.isnull().sum()
# Out:
# Movie Name            0
# Release Period        0
# Whether Remake        0
# Whether Franchise     0
# Genre                 0
# New Actor             0
# New Director          0
# New Music Director    0
# Lead Star             0
# Director              0
# Music Director        0
# Number of Screens     0
# Revenue(INR)          0
# Budget(INR)           0
# dtype: int64

# %%
drama_films.duplicated().sum()
# Out:
# 0

# %%
drama_films.nunique()
# Out:
# Movie Name            639
# Release Period          2
# Whether Remake          2
# Whether Franchise       2
# Genre                   1
# New Actor               2
# New Director            2
# New Music Director      2
# Lead Star             426
# Director              514
# Music Director        341
# Number of Screens     103
# Revenue(INR)          117
# Budget(INR)           443
# dtype: int64

# %%
px.bar(drama_films.nunique().sort_values(ascending = False), drama_films.nunique().sort_values(ascending = False), labels = {'x' : 'Number of unique values',
                                                                                                                   'index' : 'Variable Name'},
       title = 'Unique values of each columns in drama films')

# %%
print(drama_films.corr())
# Out:
#                    Number of Screens  Revenue(INR)  Budget(INR)
# Number of Screens           1.000000      0.909800     0.746226
# Revenue(INR)                0.909800      1.000000     0.790484
# Budget(INR)                 0.746226      0.790484     1.000000

# %%
sns.heatmap(drama_films.corr())
# Out:
# <AxesSubplot:>

# %%
print(drama_films.index)
# Out:
# Int64Index([   1,    3,    7,    9,   10,   12,   13,   14,   15,   19,
#             ...
#             1680, 1681, 1683, 1684, 1685, 1686, 1691, 1694, 1695, 1696],
#            dtype='int64', length=639)

# %%
px.box(drama_films, x='Number of Screens', title = "Number of Outliers in Number of Screens column of drama films")

# %%
px.box(drama_films, x='Revenue(INR)', labels = {'Revenue(INR)' : 'Amount of Money Made(INR)'},title = "Number of Outliers in Revenue(INR) column of drama films")

# %%
px.box(drama_films, x='Budget(INR)', labels = {'Budget(INR)' : 'Amount of Money Spend(INR)'}, title = "Number of Outliers in Budget(INR) column of drama films")

# %% [markdown]
# # **EDA of adult films**

# %%
adult_films = films[films["Genre"] == "adult"]
adult_films
# Out:
#                     Movie Name Release Period Whether Remake  \
# 4                    Chaatwali        Holiday             No
# 6               Dirty Marriage        Holiday             No
# 26                   Hi Fi Log        Holiday             No
# 75               Ek Aur Murder         Normal             No
# 76            Feel - The Touch         Normal             No
# ...                        ...            ...            ...
# 1561        De De Ek Chumma De         Normal             No
# 1592                  Lollypop        Holiday             No
# 1612                    Yaaraa         Normal             No
# 1626     Pyar Hawas Aur Dhokha         Normal             No
# 1641  Pehla Aashiq Pehla Qatil        Holiday             No
#
#      Whether Franchise  Genre New Actor New Director New Music Director  \
# 4                   No  adult       Yes          Yes                Yes
# 6                   No  adult       Yes           No                Yes
# ...

# %%
adult_films.head()
# Out:
#           Movie Name Release Period Whether Remake Whether Franchise  Genre  \
# 4          Chaatwali        Holiday             No                No  adult
# 6     Dirty Marriage        Holiday             No                No  adult
# 26         Hi Fi Log        Holiday             No                No  adult
# 75     Ek Aur Murder         Normal             No                No  adult
# 76  Feel - The Touch         Normal             No                No  adult
#
#    New Actor New Director New Music Director     Lead Star           Director  \
# 4        Yes          Yes                Yes    Aadil Khan         Aadil Khan
# 6        Yes           No                Yes        Aakash           Priyanka
# 26       Yes          Yes                 No  Abhay Bakshi      Baba Jagirdar
# 75       Yes           No                 No     Affi Khan        Suresh Jain
# 76        No          Yes                Yes    Afsar Khan  Shakeel S. Saifee
#
# ...

# %%
adult_films.tail()
# Out:
#                     Movie Name Release Period Whether Remake  \
# 1561        De De Ek Chumma De         Normal             No
# 1592                  Lollypop        Holiday             No
# 1612                    Yaaraa         Normal             No
# 1626     Pyar Hawas Aur Dhokha         Normal             No
# 1641  Pehla Aashiq Pehla Qatil        Holiday             No
#
#      Whether Franchise  Genre New Actor New Director New Music Director  \
# 1561                No  adult       Yes          Yes                Yes
# 1592                No  adult        No           No                 No
# 1612                No  adult       Yes           No                Yes
# 1626                No  adult       Yes           No                 No
# 1641                No  adult       Yes          Yes                Yes
#
#              Lead Star      Director    Music Director  Number of Screens  \
# 1561  Tejaswini Sarkar  Milind Swamy  Harendra Panijar                  1
# ...

# %%
adult_films.shape
# Out:
# (78, 14)

# %%
adult_films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78 entries, 4 to 1641
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Movie Name          78 non-null     object
#  1   Release Period      78 non-null     object
#  2   Whether Remake      78 non-null     object
#  3   Whether Franchise   78 non-null     object
#  4   Genre               78 non-null     object
#  5   New Actor           78 non-null     object
#  6   New Director        78 non-null     object
#  7   New Music Director  78 non-null     object
#  8   Lead Star           78 non-null     object
#  9   Director            78 non-null     object
#  10  Music Director      78 non-null     object
#  11  Number of Screens   78 non-null     int64
#  12  Revenue(INR)        78 non-null     int64
#  13  Budget(INR)         78 non-null     int64
# dtypes: int64(3), object(11)
# memory usage: 9.1+ KB

# %%
adult_films.describe()
# Out:
#        Number of Screens  Revenue(INR)   Budget(INR)
# count          78.000000  7.800000e+01  7.800000e+01
# mean           20.307692  3.957692e+06  4.591378e+06
# std            90.082546  9.057949e+06  1.819486e+07
# min             1.000000  1.000000e+06  3.500000e+04
# 25%             1.000000  1.500000e+06  6.000000e+05
# 50%             2.000000  1.500000e+06  1.075000e+06
# 75%             5.000000  2.875000e+06  2.075000e+06
# max           600.000000  6.750000e+07  1.152000e+08

# %%
adult_films.isnull().sum()
# Out:
# Movie Name            0
# Release Period        0
# Whether Remake        0
# Whether Franchise     0
# Genre                 0
# New Actor             0
# New Director          0
# New Music Director    0
# Lead Star             0
# Director              0
# Music Director        0
# Number of Screens     0
# Revenue(INR)          0
# Budget(INR)           0
# dtype: int64

# %%
adult_films.duplicated().sum()
# Out:
# 0

# %%
adult_films.nunique()
# Out:
# Movie Name            78
# Release Period         2
# Whether Remake         1
# Whether Franchise      2
# Genre                  1
# New Actor              2
# New Director           2
# New Music Director     2
# Lead Star             59
# Director              48
# Music Director        55
# Number of Screens     14
# Revenue(INR)          18
# Budget(INR)           59
# dtype: int64

# %%
px.bar(adult_films.nunique().sort_values(ascending = False), adult_films.nunique().sort_values(ascending = False), labels = {'x' : 'Number of unique values',
                                                                                                                   'index' : 'Variable Name'},
       title = 'Unique values of each columns in adult films')

# %%
print(adult_films.corr())
# Out:
#                    Number of Screens  Revenue(INR)  Budget(INR)
# Number of Screens           1.000000      0.974292     0.994254
# Revenue(INR)                0.974292      1.000000     0.959377
# Budget(INR)                 0.994254      0.959377     1.000000

# %%
sns.heatmap(adult_films.corr())
# Out:
# <AxesSubplot:>

# %%
print(adult_films.index)
# Out:
# Int64Index([   4,    6,   26,   75,   76,  194,  208,  209,  214,  215,  216,
#              217,  218,  248,  277,  300,  315,  382,  394,  417,  424,  495,
#              521,  522,  524,  572,  576,  665,  666,  716,  733,  735,  763,
#              795,  796,  803,  811,  910,  941, 1001, 1002, 1023, 1024, 1047,
#             1058, 1066, 1142, 1148, 1150, 1273, 1277, 1312, 1314, 1315, 1317,
#             1318, 1320, 1333, 1364, 1383, 1397, 1446, 1461, 1523, 1545, 1546,
#             1547, 1548, 1549, 1550, 1551, 1552, 1553, 1561, 1592, 1612, 1626,
#             1641],
#            dtype='int64')

# %%
px.box(adult_films, x='Number of Screens', title = "Number of Outliers in Number of Screens column of adult films")

# %%
px.box(adult_films,x = "Revenue(INR)", labels = {'Revenue(INR)' : 'Amount of Money Made(INR)'}, title = "Number of Outliers in Revenue(INR) column of adult films")

# %%
px.box(adult_films, x = "Budget(INR)", labels = {'Budget(INR)' : 'Amount of Money Spend(INR)'}, title = "Number of Outliers in Budget(INR) column of adult films")

# %% [markdown]
# # **EDA of thriller films**

# %%
thriller_films = films[films["Genre"] == "thriller"]
thriller_films
# Out:
#                       Movie Name Release Period Whether Remake  \
# 2               Not A Love Story        Holiday             No
# 16                       Talaash         Normal             No
# 18      Pyaar Mein Aisa Hota Hai        Holiday             No
# 20         Yehi Hai High Society        Holiday             No
# 23    Three - Love Lies Betrayal         Normal             No
# ...                          ...            ...            ...
# 1667           Mission Istaanbul         Normal             No
# 1669                      Prince         Normal             No
# 1687                     Aksar 2         Normal             No
# 1688                Hate Story 3         Normal             No
# 1692                       Speed        Holiday            Yes
#
#      Whether Franchise     Genre New Actor New Director New Music Director  \
# 2                   No  thriller        No           No                 No
# ...

# %%
thriller_films.head()
# Out:
#                     Movie Name Release Period Whether Remake  \
# 2             Not A Love Story        Holiday             No
# 16                     Talaash         Normal             No
# 18    Pyaar Mein Aisa Hota Hai        Holiday             No
# 20       Yehi Hai High Society        Holiday             No
# 23  Three - Love Lies Betrayal         Normal             No
#
#    Whether Franchise     Genre New Actor New Director New Music Director  \
# 2                 No  thriller        No           No                 No
# 16                No  thriller        No           No                 No
# 18                No  thriller       Yes          Yes                Yes
# 20                No  thriller        No           No                 No
# 23                No  thriller        No          Yes                 No
#
#             Lead Star         Director   Music Director  Number of Screens  \
# 2          Mahie Gill  Ram Gopal Verma   Sandeep Chowta                525
# ...

# %%
thriller_films.tail()
# Out:
#              Movie Name Release Period Whether Remake Whether Franchise  \
# 1667  Mission Istaanbul         Normal             No                No
# 1669             Prince         Normal             No                No
# 1687            Aksar 2         Normal             No               Yes
# 1688       Hate Story 3         Normal             No               Yes
# 1692              Speed        Holiday            Yes                No
#
#          Genre New Actor New Director New Music Director     Lead Star  \
# 1667  thriller        No           No                 No  Vivek Oberoi
# 1669  thriller        No          Yes                 No  Vivek Oberoi
# 1687  thriller        No           No                 No   Zarine Khan
# 1688  thriller        No           No                Yes   Zarine Khan
# 1692  thriller        No           No                 No    Zayed Khan
#
#               Director Music Director  Number of Screens  Revenue(INR)  \
# ...

# %%
thriller_films.shape
# Out:
# (212, 14)

# %%
thriller_films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 212 entries, 2 to 1692
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Movie Name          212 non-null    object
#  1   Release Period      212 non-null    object
#  2   Whether Remake      212 non-null    object
#  3   Whether Franchise   212 non-null    object
#  4   Genre               212 non-null    object
#  5   New Actor           212 non-null    object
#  6   New Director        212 non-null    object
#  7   New Music Director  212 non-null    object
#  8   Lead Star           212 non-null    object
#  9   Director            212 non-null    object
#  10  Music Director      212 non-null    object
#  11  Number of Screens   212 non-null    int64
#  12  Revenue(INR)        212 non-null    int64
#  13  Budget(INR)         212 non-null    int64
# dtypes: int64(3), object(11)
# memory usage: 24.8+ KB

# %%
thriller_films.describe()
# Out:
#        Number of Screens  Revenue(INR)   Budget(INR)
# count         212.000000  2.120000e+02  2.120000e+02
# mean          659.613208  1.558420e+08  1.951393e+08
# std           749.902876  2.049434e+08  3.647722e+08
# min             1.000000  1.000000e+06  7.250000e+04
# 25%            75.000000  2.687500e+07  2.637500e+06
# 50%           300.000000  7.375000e+07  3.515000e+07
# 75%          1100.000000  2.025000e+08  1.819700e+08
# max          3450.000000  1.200000e+09  1.849330e+09

# %%
thriller_films.isnull().sum()
# Out:
# Movie Name            0
# Release Period        0
# Whether Remake        0
# Whether Franchise     0
# Genre                 0
# New Actor             0
# New Director          0
# New Music Director    0
# Lead Star             0
# Director              0
# Music Director        0
# Number of Screens     0
# Revenue(INR)          0
# Budget(INR)           0
# dtype: int64

# %%
thriller_films.duplicated().sum()
# Out:
# 1

# %%
thriller_films.nunique().sort_values(ascending = False)
# Out:
# Movie Name            211
# Budget(INR)           198
# Director              163
# Lead Star             144
# Music Director        129
# Revenue(INR)           92
# Number of Screens      89
# Release Period          2
# Whether Remake          2
# Whether Franchise       2
# New Actor               2
# New Director            2
# New Music Director      2
# Genre                   1
# dtype: int64

# %%
px.bar(thriller_films.nunique().sort_values(ascending = False),thriller_films.nunique().sort_values(ascending = False), labels = {'x' : 'Number of unique values',
                                                                                                                   'index' : 'Variable Name'},
       title = 'Unique values of each columns in thriller films')

# %%
thriller_films.index
# Out:
# Int64Index([   2,   16,   18,   20,   23,   37,   40,   46,   47,   57,
#             ...
#             1618, 1621, 1622, 1653, 1660, 1667, 1669, 1687, 1688, 1692],
#            dtype='int64', length=212)

# %%
thriller_films.corr()
# Out:
#                    Number of Screens  Revenue(INR)  Budget(INR)
# Number of Screens           1.000000      0.857789     0.835032
# Revenue(INR)                0.857789      1.000000     0.858570
# Budget(INR)                 0.835032      0.858570     1.000000

# %%
sns.heatmap(thriller_films.corr())
# Out:
# <AxesSubplot:>

# %%
px.box(thriller_films, x = "Number of Screens", title = "Number of Outliers in Number of Screens column of thriller films")

# %%
px.box(thriller_films, x = "Revenue(INR)", labels = {'Revenue(INR)' : 'Amount of Money Made(INR)'}, title = "Number of Outliers in Revenue(INR) column of thriller films")

# %%
px.box(thriller_films, x = "Budget(INR)", labels = {'Budget(INR)' : 'Amount of Money Spend(INR)'}, title = "Number of Outliers in Budget(INR) column of thriller films")

# %% [markdown]
# # **EDA of romance films**

# %%
romance_films = films[films['Genre'] == "love_story"]
romance_films
# Out:
#                          Movie Name Release Period Whether Remake  \
# 11                            Fanaa         Normal             No
# 21                  Say Yes To Love         Normal             No
# 22    Dreams - Sapnay Sach Honge...        Holiday             No
# 35                    Ahista Ahista        Holiday             No
# 58                   Haal - E - Dil         Normal             No
# ...                             ...            ...            ...
# 1598         Guardians Who Loved Us         Normal             No
# 1605          Badrinath Ki Dulhania        Holiday             No
# 1673                          Kisna        Holiday             No
# 1682                Pyaar Kaa Funda        Holiday             No
# 1690          Love Breakups Zindagi         Normal             No
#
#      Whether Franchise       Genre New Actor New Director New Music Director  \
# 11                  No  love_story        No           No                 No
# ...

# %%
romance_films.head()
# Out:
#                        Movie Name Release Period Whether Remake  \
# 11                          Fanaa         Normal             No
# 21                Say Yes To Love         Normal             No
# 22  Dreams - Sapnay Sach Honge...        Holiday             No
# 35                  Ahista Ahista        Holiday             No
# 58                 Haal - E - Dil         Normal             No
#
#    Whether Franchise       Genre New Actor New Director New Music Director  \
# 11                No  love_story        No           No                 No
# 21                No  love_story       Yes           No                 No
# 22                No  love_story       Yes          Yes                 No
# 35                No  love_story        No          Yes                 No
# 58                No  love_story       Yes           No                 No
#
#           Lead Star         Director     Music Director  Number of Screens  \
# ...

# %%
romance_films.tail()
# Out:
#                   Movie Name Release Period Whether Remake Whether Franchise  \
# 1598  Guardians Who Loved Us         Normal             No                No
# 1605   Badrinath Ki Dulhania        Holiday             No               Yes
# 1673                   Kisna        Holiday             No                No
# 1682         Pyaar Kaa Funda        Holiday             No                No
# 1690   Love Breakups Zindagi         Normal             No                No
#
#            Genre New Actor New Director New Music Director        Lead Star  \
# 1598  love_story       Yes          Yes                 No       V.P. Singh
# 1605  love_story        No           No                Yes     Varun Dhawan
# 1673  love_story        No           No                 No     Vivek Oberoi
# 1682  love_story       Yes          Yes                 No  Yugboah Garewal
# 1690  love_story        No          Yes                 No       Zayed Khan
#
# ...

# %%
romance_films.shape
# Out:
# (133, 14)

# %%
romance_films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 133 entries, 11 to 1690
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Movie Name          133 non-null    object
#  1   Release Period      133 non-null    object
#  2   Whether Remake      133 non-null    object
#  3   Whether Franchise   133 non-null    object
#  4   Genre               133 non-null    object
#  5   New Actor           133 non-null    object
#  6   New Director        133 non-null    object
#  7   New Music Director  133 non-null    object
#  8   Lead Star           133 non-null    object
#  9   Director            133 non-null    object
#  10  Music Director      133 non-null    object
#  11  Number of Screens   133 non-null    int64
#  12  Revenue(INR)        133 non-null    int64
#  13  Budget(INR)         133 non-null    int64
# dtypes: int64(3), object(11)
# memory usage: 15.6+ KB

# %%
romance_films.describe()
# Out:
#        Number of Screens  Revenue(INR)   Budget(INR)
# count         133.000000  1.330000e+02  1.330000e+02
# mean          571.601504  1.544323e+08  2.565923e+08
# std           718.184389  1.900253e+08  5.123711e+08
# min             1.000000  1.500000e+06  6.500000e+04
# 25%            50.000000  2.250000e+07  1.375000e+06
# 50%           275.000000  8.000000e+07  1.910000e+07
# 75%           825.000000  2.200000e+08  2.781500e+08
# max          3000.000000  9.800000e+08  2.956130e+09

# %%
romance_films.isnull().sum()
# Out:
# Movie Name            0
# Release Period        0
# Whether Remake        0
# Whether Franchise     0
# Genre                 0
# New Actor             0
# New Director          0
# New Music Director    0
# Lead Star             0
# Director              0
# Music Director        0
# Number of Screens     0
# Revenue(INR)          0
# Budget(INR)           0
# dtype: int64

# %%
romance_films.duplicated().sum()
# Out:
# 0

# %%
romance_films.nunique()
# Out:
# Movie Name            132
# Release Period          2
# Whether Remake          2
# Whether Franchise       2
# Genre                   1
# New Actor               2
# New Director            2
# New Music Director      2
# Lead Star             101
# Director              119
# Music Director         82
# Number of Screens      66
# Revenue(INR)           70
# Budget(INR)           126
# dtype: int64

# %%
px.bar(romance_films.nunique().sort_values(ascending = False),romance_films.nunique().sort_values(ascending = False), labels = {'x' : 'Number of unique values',
                                                                                                                   'index' : 'Variable Name'},
       title = 'Unique values of each columns in romance films')

# %%
romance_films.index
# Out:
# Int64Index([  11,   21,   22,   35,   58,   70,   71,   73,   90,  144,
#             ...
#             1520, 1539, 1558, 1579, 1593, 1598, 1605, 1673, 1682, 1690],
#            dtype='int64', length=133)

# %%
romance_films.corr()
# Out:
#                    Number of Screens  Revenue(INR)  Budget(INR)
# Number of Screens           1.000000      0.903427     0.805609
# Revenue(INR)                0.903427      1.000000     0.832894
# Budget(INR)                 0.805609      0.832894     1.000000

# %%
sns.heatmap(romance_films.corr())
# Out:
# <AxesSubplot:>

# %%
px.box(romance_films, x = "Number of Screens", title = "Number of Outliers in Number of Screens column of romance films")

# %%
px.box(romance_films, x = "Revenue(INR)", labels = {'Revenue(INR)' : 'Amount of Money Made(INR)'}, title = "Number of Outliers in Revenue(INR) column of romance films")

# %%
px.box(romance_films, x = "Budget(INR)", labels = {'Budget(INR)' : 'Amount of Money Spend(INR)'}, title = "Number of Outliers in Budget(INR) column of romance films")

# %% [markdown]
# # **EDA of rom_com films**

# %%
romcom_films = films[films["Genre"] == "rom__com"]
romcom_films
# Out:
#                        Movie Name Release Period Whether Remake  \
# 28                     One By Two         Normal             No
# 30                   Socha Na Tha        Holiday             No
# 31             Happy Bhaag Jayegi         Normal             No
# 33    Honeymoon Travels Pvt. Ltd.         Normal             No
# 49            Jhoom Barabar Jhoom         Normal             No
# ...                           ...            ...            ...
# 1661           Amit Sahni Ki List         Normal             No
# 1672      Kismet Love Paisa Dilli         Normal             No
# 1674                Home Delivery         Normal             No
# 1675    Jayantabhai Ki Love Story        Holiday             No
# 1676              Impatient Vivek         Normal             No
#
#      Whether Franchise     Genre New Actor New Director New Music Director  \
# 28                  No  rom__com        No          Yes                 No
# ...

# %%
romcom_films.head()
# Out:
#                      Movie Name Release Period Whether Remake  \
# 28                   One By Two         Normal             No
# 30                 Socha Na Tha        Holiday             No
# 31           Happy Bhaag Jayegi         Normal             No
# 33  Honeymoon Travels Pvt. Ltd.         Normal             No
# 49          Jhoom Barabar Jhoom         Normal             No
#
#    Whether Franchise     Genre New Actor New Director New Music Director  \
# 28                No  rom__com        No          Yes                 No
# 30                No  rom__com       Yes          Yes                 No
# 31                No  rom__com        No           No                 No
# 33                No  rom__com        No          Yes                 No
# 49                No  rom__com        No           No                 No
#
#             Lead Star       Director          Music Director  \
# 28         Abhay Deol  Devika Bhagat  Shankar - Ehsaan - Loy
# ...

# %%
romcom_films.tail()
# Out:
#                      Movie Name Release Period Whether Remake  \
# 1661         Amit Sahni Ki List         Normal             No
# 1672    Kismet Love Paisa Dilli         Normal             No
# 1674              Home Delivery         Normal             No
# 1675  Jayantabhai Ki Love Story        Holiday             No
# 1676            Impatient Vivek         Normal             No
#
#      Whether Franchise     Genre New Actor New Director New Music Director  \
# 1661                No  rom__com        No          Yes                 No
# 1672                No  rom__com        No           No                 No
# 1674                No  rom__com        No           No                 No
# 1675                No  rom__com        No          Yes                 No
# 1676                No  rom__com       Yes           No                Yes
#
#             Lead Star         Director      Music Director  Number of Screens  \
# ...

# %%
romcom_films.shape
# Out:
# (95, 14)

# %%
romcom_films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95 entries, 28 to 1676
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Movie Name          95 non-null     object
#  1   Release Period      95 non-null     object
#  2   Whether Remake      95 non-null     object
#  3   Whether Franchise   95 non-null     object
#  4   Genre               95 non-null     object
#  5   New Actor           95 non-null     object
#  6   New Director        95 non-null     object
#  7   New Music Director  95 non-null     object
#  8   Lead Star           95 non-null     object
#  9   Director            95 non-null     object
#  10  Music Director      95 non-null     object
#  11  Number of Screens   95 non-null     int64
#  12  Revenue(INR)        95 non-null     int64
#  13  Budget(INR)         95 non-null     int64
# dtypes: int64(3), object(11)
# memory usage: 11.1+ KB

# %%
romcom_films.describe()
# Out:
#        Number of Screens  Revenue(INR)   Budget(INR)
# count          95.000000  9.500000e+01  9.500000e+01
# mean          712.452632  1.993232e+08  2.950743e+08
# std           624.814249  1.937527e+08  4.104995e+08
# min             3.000000  3.500000e+06  7.000000e+04
# 25%           200.000000  6.375000e+07  1.480000e+07
# 50%           600.000000  1.500000e+08  1.378850e+08
# 75%          1000.000000  2.700000e+08  4.173975e+08
# max          3200.000000  1.190000e+09  2.436435e+09

# %%
romcom_films.isnull().sum()
# Out:
# Movie Name            0
# Release Period        0
# Whether Remake        0
# Whether Franchise     0
# Genre                 0
# New Actor             0
# New Director          0
# New Music Director    0
# Lead Star             0
# Director              0
# Music Director        0
# Number of Screens     0
# Revenue(INR)          0
# Budget(INR)           0
# dtype: int64

# %%
romcom_films.duplicated().sum()
# Out:
# 0

# %%
romcom_films.nunique()
# Out:
# Movie Name            95
# Release Period         2
# Whether Remake         2
# Whether Franchise      2
# Genre                  1
# New Actor              2
# New Director           2
# New Music Director     2
# Lead Star             65
# Director              84
# Music Director        47
# Number of Screens     61
# Revenue(INR)          61
# Budget(INR)           95
# dtype: int64

# %%
px.bar(romcom_films.nunique().sort_values(ascending = False),romcom_films.nunique().sort_values(ascending = False), labels = {'x' : 'Number of unique values',
                                                                                                                   'index' : 'Variable Name'},
       title = 'Unique values of each columns in romcom films')

# %%
romcom_films.index
# Out:
# Int64Index([  28,   30,   31,   33,   49,   50,   55,   82,  168,  193,  204,
#              222,  231,  299,  309,  321,  346,  347,  348,  355,  376,  437,
#              469,  470,  479,  487,  490,  491,  501,  525,  579,  580,  581,
#              583,  594,  609,  616,  623,  644,  651,  694,  699,  700,  772,
#              799,  806,  861,  862,  878,  966,  967,  987,  989, 1038, 1069,
#             1106, 1107, 1116, 1127, 1129, 1138, 1162, 1164, 1175, 1188, 1217,
#             1218, 1225, 1229, 1246, 1252, 1264, 1268, 1323, 1346, 1347, 1348,
#             1349, 1360, 1373, 1390, 1440, 1459, 1498, 1521, 1576, 1587, 1602,
#             1604, 1647, 1661, 1672, 1674, 1675, 1676],
#            dtype='int64')

# %%
romcom_films.corr()
# Out:
#                    Number of Screens  Revenue(INR)  Budget(INR)
# Number of Screens           1.000000      0.891743     0.812583
# Revenue(INR)                0.891743      1.000000     0.744844
# Budget(INR)                 0.812583      0.744844     1.000000

# %%
sns.heatmap(romcom_films.corr())
# Out:
# <AxesSubplot:>

# %%
px.box(romcom_films, x = "Number of Screens", title = "Number of Outliers in Number of Screens column of romcom films")

# %%
px.box(romcom_films, x = "Revenue(INR)", labels = {'Revenue(INR)' : 'Amount of Money Made(INR)'}, title = "Number of Outliers in Revenue(INR) column of romcom films")

# %%
px.box(romcom_films, x = "Budget(INR)", labels = {'Budget(INR)' : 'Amount of Money Spend(INR)'}, title = "Number of Outliers in Budget(INR) column of romcom films")

# %% [markdown]
# # **EDA of suspense films**

# %%
mystery_films = films[films["Genre"] == "suspense"]
mystery_films
# Out:
#                           Movie Name Release Period Whether Remake  \
# 0                        Golden Boys         Normal             No
# 32           Manorama Six Feet Under         Normal             No
# 184                            Pizza         Normal             No
# 186                    36 China Town        Holiday            Yes
# 282             Chalo Picnic Manayen         Normal             No
# 324                 Kyun Hua Achanak        Holiday             No
# 327                With Love, Delhi!         Normal             No
# 407                      Chargesheet        Holiday             No
# 420                  Bollywood Villa         Normal             No
# 427            Gumnaam - The Mystery         Normal             No
# 588                              Rog         Normal             No
# 596                         C U At 9         Normal             No
# 684               Nishaan - The Mark         Normal             No
# ...

# %%
mystery_films.head()
# Out:
#                   Movie Name Release Period Whether Remake Whether Franchise  \
# 0                Golden Boys         Normal             No                No
# 32   Manorama Six Feet Under         Normal             No                No
# 184                    Pizza         Normal             No                No
# 186            36 China Town        Holiday            Yes                No
# 282     Chalo Picnic Manayen         Normal             No                No
#
#         Genre New Actor New Director New Music Director          Lead Star  \
# 0    suspense       Yes           No                 No       Jeet Goswami
# 32   suspense        No          Yes                Yes         Abhay Deol
# 184  suspense        No          Yes                 No      Akshay Oberoi
# 186  suspense        No           No                 No     Akshaye Khanna
# 282  suspense       Yes          Yes                Yes  Arjun Chakraborty
#
# ...

# %%
mystery_films.tail()
# Out:
#                      Movie Name Release Period Whether Remake  \
# 1400  Chehra - The Unknown Mask         Normal             No
# 1430        Raat Abhi Baaki Hai        Holiday             No
# 1441            Woodstock Villa         Normal             No
# 1610    Real Life Of Supermodel         Normal             No
# 1633   Mahiya - Call Of Love...         Normal             No
#
#      Whether Franchise     Genre New Actor New Director New Music Director  \
# 1400                No  suspense       Yes          Yes                Yes
# 1430                No  suspense       Yes          Yes                Yes
# 1441                No  suspense       Yes           No                 No
# 1610                No  suspense        No          Yes                Yes
# 1633                No  suspense       Yes          Yes                Yes
#
#            Lead Star            Director Music Director  Number of Screens  \
# ...

# %%
mystery_films.shape
# Out:
# (30, 14)

# %%
mystery_films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 0 to 1633
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Movie Name          30 non-null     object
#  1   Release Period      30 non-null     object
#  2   Whether Remake      30 non-null     object
#  3   Whether Franchise   30 non-null     object
#  4   Genre               30 non-null     object
#  5   New Actor           30 non-null     object
#  6   New Director        30 non-null     object
#  7   New Music Director  30 non-null     object
#  8   Lead Star           30 non-null     object
#  9   Director            30 non-null     object
#  10  Music Director      30 non-null     object
#  11  Number of Screens   30 non-null     int64
#  12  Revenue(INR)        30 non-null     int64
#  13  Budget(INR)         30 non-null     int64
# dtypes: int64(3), object(11)
# memory usage: 3.5+ KB

# %%
mystery_films.describe()
# Out:
#        Number of Screens  Revenue(INR)   Budget(INR)
# count          30.000000  3.000000e+01  3.000000e+01
# mean          175.666667  3.875000e+07  2.062833e+07
# std           202.504037  4.422489e+07  6.872350e+07
# min             1.000000  2.500000e+06  3.500000e+04
# 25%            21.250000  1.000000e+07  4.437500e+05
# 50%            75.000000  2.500000e+07  2.975000e+06
# 75%           293.750000  4.937500e+07  1.347500e+07
# max           625.000000  1.900000e+08  3.792000e+08

# %%
mystery_films.isnull().sum()
# Out:
# Movie Name            0
# Release Period        0
# Whether Remake        0
# Whether Franchise     0
# Genre                 0
# New Actor             0
# New Director          0
# New Music Director    0
# Lead Star             0
# Director              0
# Music Director        0
# Number of Screens     0
# Revenue(INR)          0
# Budget(INR)           0
# dtype: int64

# %%
mystery_films.duplicated().sum()
# Out:
# 0

# %%
mystery_films.nunique()
# Out:
# Movie Name            30
# Release Period         2
# Whether Remake         2
# Whether Franchise      1
# Genre                  1
# New Actor              2
# New Director           2
# New Music Director     2
# Lead Star             29
# Director              29
# Music Director        28
# Number of Screens     25
# Revenue(INR)          21
# Budget(INR)           30
# dtype: int64

# %%
px.bar(mystery_films.nunique().sort_values(ascending = False), mystery_films.nunique().sort_values(ascending = False), labels = {'x' : 'Number of unique values',
                                                                                                                   'index' : 'Variable Name'},
       title = 'Unique values of each columns in mystery films')

# %%
mystery_films.index
# Out:
# Int64Index([   0,   32,  184,  186,  282,  324,  327,  407,  420,  427,  588,
#              596,  684,  709,  710,  760,  781,  860,  925,  983, 1025, 1040,
#             1044, 1072, 1329, 1400, 1430, 1441, 1610, 1633],
#            dtype='int64')

# %%
mystery_films.corr()
# Out:
#                    Number of Screens  Revenue(INR)  Budget(INR)
# Number of Screens           1.000000      0.826596     0.376612
# Revenue(INR)                0.826596      1.000000     0.732973
# Budget(INR)                 0.376612      0.732973     1.000000

# %%
sns.heatmap(mystery_films.corr())
# Out:
# <AxesSubplot:>

# %%
px.box(mystery_films, x = "Number of Screens", title = "Number of Outliers in Number of Screens column of mystery films")

# %%
px.box(mystery_films, x = "Revenue(INR)", labels = {'Revenue(INR)' : 'Amount of Money Made(INR)'}, title = "Number of Outliers in Revenue(INR) column of mystery films")

# %%
px.box(mystery_films, x = "Budget(INR)", labels = {'Budget(INR)' : 'Amount of Money Spend(INR)'}, title = "Number of Outliers in Budget(INR) column of mystery films")

# %% [markdown]
# # **EDA of horror films**

# %%
horror_films = films[films["Genre"] == "horror"]
horror_films
# Out:
#                           Movie Name Release Period Whether Remake  \
# 67                           Shaapit         Normal             No
# 77               1920 - Evil Returns        Holiday             No
# 198                      Khamoshiyan         Normal             No
# 320                           Ghutan         Normal             No
# 336                 Gauri The Unborn         Normal             No
# 338             Aagaah - The Warning         Normal             No
# 359                            Aatma         Normal             No
# 363                      Creature 3D         Normal             No
# 367                             Help        Holiday             No
# 380                   Ek Main Ek Tum         Normal             No
# 453     Raaz - The Mystery Continues        Holiday             No
# 462                           Raaz 3         Normal             No
# 464                      Raaz Reboot         Normal             No
# ...

# %%
horror_films.head()
# Out:
#               Movie Name Release Period Whether Remake Whether Franchise  \
# 67               Shaapit         Normal             No                No
# 77   1920 - Evil Returns        Holiday             No               Yes
# 198          Khamoshiyan         Normal             No                No
# 320               Ghutan         Normal             No                No
# 336     Gauri The Unborn         Normal             No                No
#
#       Genre New Actor New Director New Music Director         Lead Star  \
# 67   horror       Yes           No                Yes    Aditya Narayan
# 77   horror        No          Yes                 No  Aftab Shivdasani
# 198  horror        No          Yes                Yes         Ali Fazal
# 320  horror        No           No                Yes        Aryan Vaid
# 336  horror        No          Yes                 No     Atul Kulkarni
#
#           Director    Music Director  Number of Screens  Revenue(INR)  \
# ...

# %%
horror_films.tail()
# Out:
#                     Movie Name Release Period Whether Remake  \
# 1530  Machhali Jal Ki Rani Hai         Normal             No
# 1536                     Kaalo        Holiday             No
# 1569           Ab Tumhari Bari         Normal             No
# 1594                     Naina        Holiday             No
# 1609             Mumbai 125 KM         Normal             No
#
#      Whether Franchise   Genre New Actor New Director New Music Director  \
# 1530                No  horror        No          Yes                Yes
# 1536                No  horror       Yes           No                 No
# 1569                No  horror       Yes           No                Yes
# 1594                No  horror        No          Yes                 No
# 1609                No  horror        No           No                 No
#
#              Lead Star          Director    Music Director  Number of Screens  \
# ...

# %%
horror_films.shape
# Out:
# (53, 14)

# %%
horror_films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53 entries, 67 to 1609
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Movie Name          53 non-null     object
#  1   Release Period      53 non-null     object
#  2   Whether Remake      53 non-null     object
#  3   Whether Franchise   53 non-null     object
#  4   Genre               53 non-null     object
#  5   New Actor           53 non-null     object
#  6   New Director        53 non-null     object
#  7   New Music Director  53 non-null     object
#  8   Lead Star           53 non-null     object
#  9   Director            53 non-null     object
#  10  Music Director      53 non-null     object
#  11  Number of Screens   53 non-null     int64
#  12  Revenue(INR)        53 non-null     int64
#  13  Budget(INR)         53 non-null     int64
# dtypes: int64(3), object(11)
# memory usage: 6.2+ KB

# %%
horror_films.describe()
# Out:
#        Number of Screens  Revenue(INR)   Budget(INR)
# count          53.000000  5.300000e+01  5.300000e+01
# mean          530.075472  7.110377e+07  9.700698e+07
# std           596.698605  7.772736e+07  1.756349e+08
# min             1.000000  1.500000e+06  7.500000e+04
# 25%            25.000000  1.250000e+07  1.800000e+06
# 50%           325.000000  4.500000e+07  1.490000e+07
# 75%           800.000000  9.000000e+07  1.043000e+08
# max          2300.000000  3.100000e+08  9.526625e+08

# %%
horror_films.isnull().sum()
# Out:
# Movie Name            0
# Release Period        0
# Whether Remake        0
# Whether Franchise     0
# Genre                 0
# New Actor             0
# New Director          0
# New Music Director    0
# Lead Star             0
# Director              0
# Music Director        0
# Number of Screens     0
# Revenue(INR)          0
# Budget(INR)           0
# dtype: int64

# %%
horror_films.duplicated().sum()
# Out:
# 1

# %%
horror_films.nunique()
# Out:
# Movie Name            52
# Release Period         2
# Whether Remake         2
# Whether Franchise      2
# Genre                  1
# New Actor              2
# New Director           2
# New Music Director     2
# Lead Star             46
# Director              36
# Music Director        44
# Number of Screens     42
# Revenue(INR)          34
# Budget(INR)           51
# dtype: int64

# %%
px.bar(horror_films.nunique().sort_values(ascending = False), horror_films.nunique().sort_values(ascending = False), labels = {'x' : 'Number of unique values',
                                                                                                                   'index' : 'Variable Name'},
       title = 'Unique values of each columns in horror films')

# %%
horror_films.index
# Out:
# Int64Index([  67,   77,  198,  320,  336,  338,  359,  363,  367,  380,  453,
#              462,  464,  466,  543,  602,  641,  683,  687,  697,  736,  754,
#              762,  778,  802,  909,  915,  943,  944,  965,  993,  996, 1068,
#             1074, 1091, 1126, 1310, 1313, 1316, 1382, 1393, 1399, 1406, 1424,
#             1469, 1470, 1505, 1510, 1530, 1536, 1569, 1594, 1609],
#            dtype='int64')

# %%
horror_films.corr()
# Out:
#                    Number of Screens  Revenue(INR)  Budget(INR)
# Number of Screens           1.000000      0.915518     0.836580
# Revenue(INR)                0.915518      1.000000     0.808572
# Budget(INR)                 0.836580      0.808572     1.000000

# %%
sns.heatmap(horror_films.corr())
# Out:
# <AxesSubplot:>

# %%
px.box(horror_films, x = "Number of Screens", title = "Number of Outliers in Number of Screens column of horror films")

# %%
px.box(horror_films, x = "Revenue(INR)", labels = {'Revenue(INR)' : 'Amount of Money Made(INR)'}, title = "Number of Outliers in Revenue(INR) column of horror films")

# %%
px.box(horror_films, x = "Budget(INR)", labels = {'Budget(INR)' : 'Amount of Money Spend(INR)'}, title = "Number of Outliers in Budget(INR) column of horror films")

# %% [markdown]
# # **EDA of fantasy films**

# %%
fantasy_films = films[films["Genre"] == "fantasy"]
fantasy_films
# Out:
#                         Movie Name Release Period Whether Remake  \
# 79                  Jaane Hoga Kya         Normal             No
# 101          Toonpur Ka Superrhero        Holiday             No
# 173                          Joker         Normal             No
# 265                      Chhutanki         Normal             No
# 307              Hum Tum Aur Ghost         Normal             No
# 385              Maruti Mera Dosst         Normal             No
# 393                       Zokkomon        Holiday             No
# 463                          Mr. X         Normal             No
# 535                Love Story 2050        Holiday             No
# 557   5ters: Castle of Dark Master         Normal             No
# 1176       Jaane Kahan Se Aayi Hai         Normal             No
# 1179                        Aladin        Holiday             No
# 1209           Ramaa - The Saviour         Normal             No
#
# ...

# %%
fantasy_films.head()
# Out:
#                 Movie Name Release Period Whether Remake Whether Franchise  \
# 79          Jaane Hoga Kya         Normal             No                No
# 101  Toonpur Ka Superrhero        Holiday             No                No
# 173                  Joker         Normal             No                No
# 265              Chhutanki         Normal             No                No
# 307      Hum Tum Aur Ghost         Normal             No                No
#
#        Genre New Actor New Director New Music Director         Lead Star  \
# 79   fantasy        No          Yes                 No  Aftab Shivdasani
# 101  fantasy        No          Yes                 No        Ajay Devgn
# 173  fantasy        No           No                Yes      Akshay Kumar
# 265  fantasy       Yes           No                Yes       Anuj Pandit
# 307  fantasy        No           No                 No      Arshad Warsi
#
# ...

# %%
fantasy_films.tail()
# Out:
#                         Movie Name Release Period Whether Remake  \
# 535                Love Story 2050        Holiday             No
# 557   5ters: Castle of Dark Master         Normal             No
# 1176       Jaane Kahan Se Aayi Hai         Normal             No
# 1179                        Aladin        Holiday             No
# 1209           Ramaa - The Saviour         Normal             No
#
#      Whether Franchise    Genre New Actor New Director New Music Director  \
# 535                 No  fantasy       Yes           No                 No
# 557                 No  fantasy       Yes          Yes                Yes
# 1176                No  fantasy        No          Yes                 No
# 1179                No  fantasy        No           No                 No
# 1209                No  fantasy        No          Yes                 No
#
#              Lead Star      Director     Music Director  Number of Screens  \
# ...

# %%
fantasy_films.shape
# Out:
# (13, 14)

# %%
fantasy_films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 79 to 1209
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Movie Name          13 non-null     object
#  1   Release Period      13 non-null     object
#  2   Whether Remake      13 non-null     object
#  3   Whether Franchise   13 non-null     object
#  4   Genre               13 non-null     object
#  5   New Actor           13 non-null     object
#  6   New Director        13 non-null     object
#  7   New Music Director  13 non-null     object
#  8   Lead Star           13 non-null     object
#  9   Director            13 non-null     object
#  10  Music Director      13 non-null     object
#  11  Number of Screens   13 non-null     int64
#  12  Revenue(INR)        13 non-null     int64
#  13  Budget(INR)         13 non-null     int64
# dtypes: int64(3), object(11)
# memory usage: 1.5+ KB

# %%
fantasy_films.describe()
# Out:
#        Number of Screens  Revenue(INR)   Budget(INR)
# count          13.000000  1.300000e+01  1.300000e+01
# mean          584.615385  1.996154e+08  8.581202e+07
# std           691.009110  1.672319e+08  1.131825e+08
# min            10.000000  1.750000e+07  7.250000e+04
# 25%            95.000000  5.500000e+07  2.850000e+06
# 50%           425.000000  1.800000e+08  5.104625e+07
# 75%           600.000000  3.700000e+08  1.089500e+08
# max          2100.000000  4.700000e+08  3.210875e+08

# %%
fantasy_films.isnull().sum()
# Out:
# Movie Name            0
# Release Period        0
# Whether Remake        0
# Whether Franchise     0
# Genre                 0
# New Actor             0
# New Director          0
# New Music Director    0
# Lead Star             0
# Director              0
# Music Director        0
# Number of Screens     0
# Revenue(INR)          0
# Budget(INR)           0
# dtype: int64

# %%
fantasy_films.duplicated().sum()
# Out:
# 0

# %%
fantasy_films.nunique()
# Out:
# Movie Name            13
# Release Period         2
# Whether Remake         1
# Whether Franchise      1
# Genre                  1
# New Actor              2
# New Director           2
# New Music Director     2
# Lead Star             12
# Director              13
# Music Director        10
# Number of Screens     13
# Revenue(INR)          12
# Budget(INR)           13
# dtype: int64

# %%
px.bar(fantasy_films.nunique().sort_values(ascending = False), fantasy_films.nunique().sort_values(ascending = False), labels = {'x' : 'Number of unique values',
                                                                                                                   'index' : 'Variable Name'},
       title = 'Unique values of each columns in fantasy films')

# %%
fantasy_films.index
# Out:
# Int64Index([79, 101, 173, 265, 307, 385, 393, 463, 535, 557, 1176, 1179, 1209], dtype='int64')

# %%
fantasy_films.corr()
# Out:
#                    Number of Screens  Revenue(INR)  Budget(INR)
# Number of Screens           1.000000      0.818035     0.978957
# Revenue(INR)                0.818035      1.000000     0.873713
# Budget(INR)                 0.978957      0.873713     1.000000

# %%
sns.heatmap(fantasy_films.corr())
# Out:
# <AxesSubplot:>

# %%
px.box(fantasy_films, x = "Number of Screens", title = "Number of Outliers in Number of Screens column of fantasy films")

# %%
px.box(fantasy_films, x = "Revenue(INR)", labels = {'Revenue(INR)' : 'Amount of Money Made(INR)'}, title = "Number of Outliers in Revenue(INR) column of fantasy films")

# %%
px.box(fantasy_films, x = "Budget(INR)", labels = {'Budget(INR)' : 'Amount of Money Spend(INR)'}, title = "Number of Outliers in Budget(INR) column of fantasy films")

# %% [markdown]
# # **EDA of masala films**

# %%
masala_films = films[films["Genre"] == "masala"]
masala_films
# Out:
#                        Movie Name Release Period Whether Remake  \
# 95                 Son Of Sardaar        Holiday            Yes
# 122                    Himmatwala        Holiday            Yes
# 139                Singh Is Kinng         Normal             No
# 159                Singh Is Bling        Holiday             No
# 285                         Tevar         Normal            Yes
# 946      Bahubali - The Beginning         Normal             No
# 947   Bahubali 2 - The Conclusion        Holiday             No
# 1128                       Gunday        Holiday             No
# 1239                       Sultan        Holiday             No
# 1248            Bajrangi Bhaijaan        Holiday             No
# 1369                 Om Shanti Om        Holiday             No
# 1370               Happy New Year        Holiday             No
# 1378              Chennai Express        Holiday             No
# 1379                      Dilwale         Normal             No
# ...

# %%
masala_films.head()
# Out:
#          Movie Name Release Period Whether Remake Whether Franchise   Genre  \
# 95   Son Of Sardaar        Holiday            Yes                No  masala
# 122      Himmatwala        Holiday            Yes                No  masala
# 139  Singh Is Kinng         Normal             No                No  masala
# 159  Singh Is Bling        Holiday             No                No  masala
# 285           Tevar         Normal            Yes                No  masala
#
#     New Actor New Director New Music Director     Lead Star  \
# 95         No           No                 No    Ajay Devgn
# 122        No           No                 No    Ajay Devgn
# 139        No           No                 No  Akshay Kumar
# 159        No           No                 No  Akshay Kumar
# 285        No          Yes                Yes  Arjun Kapoor
#
#                      Director     Music Director  Number of Screens  \
# 95               Ashwini Dhir  Himesh Reshammiya               2000
# ...

# %%
masala_films.tail()
# Out:
#            Movie Name Release Period Whether Remake Whether Franchise   Genre  \
# 1370   Happy New Year        Holiday             No                No  masala
# 1378  Chennai Express        Holiday             No                No  masala
# 1379          Dilwale         Normal             No                No  masala
# 1564    A Flying Jatt        Holiday             No                No  masala
# 1601         Judwaa 2        Holiday             No               Yes  masala
#
#      New Actor New Director New Music Director      Lead Star      Director  \
# 1370        No           No                 No  Shahrukh Khan    Farah Khan
# 1378        No           No                Yes  Shahrukh Khan  Rohit Shetty
# 1379        No           No                 No  Shahrukh Khan  Rohit Shetty
# 1564        No           No                 No   Tiger Shroff  Remo D'Souza
# 1601        No           No                 No   Varun Dhawan  David Dhawan
#
# ...

# %%
masala_films.shape
# Out:
# (16, 14)

# %%
masala_films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 95 to 1601
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Movie Name          16 non-null     object
#  1   Release Period      16 non-null     object
#  2   Whether Remake      16 non-null     object
#  3   Whether Franchise   16 non-null     object
#  4   Genre               16 non-null     object
#  5   New Actor           16 non-null     object
#  6   New Director        16 non-null     object
#  7   New Music Director  16 non-null     object
#  8   Lead Star           16 non-null     object
#  9   Director            16 non-null     object
#  10  Music Director      16 non-null     object
#  11  Number of Screens   16 non-null     int64
#  12  Revenue(INR)        16 non-null     int64
#  13  Budget(INR)         16 non-null     int64
# dtypes: int64(3), object(11)
# memory usage: 1.9+ KB

# %%
masala_films.describe()
# Out:
#        Number of Screens  Revenue(INR)   Budget(INR)
# count          16.000000  1.600000e+01  1.600000e+01
# mean         2946.875000  1.002500e+09  2.684071e+09
# std           975.443275  5.146455e+08  2.262597e+09
# min          1200.000000  4.000000e+08  4.933688e+08
# 25%          2487.500000  5.475000e+08  1.229311e+09
# 50%          3125.000000  7.950000e+08  1.590538e+09
# 75%          3662.500000  1.462500e+09  3.781547e+09
# max          4350.000000  1.950000e+09  8.016120e+09

# %%
masala_films.isnull().sum()
# Out:
# Movie Name            0
# Release Period        0
# Whether Remake        0
# Whether Franchise     0
# Genre                 0
# New Actor             0
# New Director          0
# New Music Director    0
# Lead Star             0
# Director              0
# Music Director        0
# Number of Screens     0
# Revenue(INR)          0
# Budget(INR)           0
# dtype: int64

# %%
masala_films.duplicated().sum()
# Out:
# 0

# %%
masala_films.nunique()
# Out:
# Movie Name            16
# Release Period         2
# Whether Remake         2
# Whether Franchise      2
# Genre                  1
# New Actor              2
# New Director           2
# New Music Director     2
# Lead Star              9
# Director              12
# Music Director         9
# Number of Screens     15
# Revenue(INR)          16
# Budget(INR)           16
# dtype: int64

# %%
px.bar(masala_films.nunique().sort_values(ascending = False), masala_films.nunique().sort_values(ascending = False), labels = {'x' : 'Number of unique values',
                                                                                                                   'index' : 'Variable Name'},
       title = 'Unique values of each columns in masala films')

# %%
masala_films.index
# Out:
# Int64Index([  95,  122,  139,  159,  285,  946,  947, 1128, 1239, 1248, 1369,
#             1370, 1378, 1379, 1564, 1601],
#            dtype='int64')

# %%
masala_films.corr()
# Out:
#                    Number of Screens  Revenue(INR)  Budget(INR)
# Number of Screens           1.000000      0.499478     0.677655
# Revenue(INR)                0.499478      1.000000     0.767095
# Budget(INR)                 0.677655      0.767095     1.000000

# %%
sns.heatmap(masala_films.corr())
# Out:
# <AxesSubplot:>

# %%
px.box(masala_films, x = "Number of Screens", title = "Number of Outliers in Number of Screens column of masala films")

# %%
px.box(masala_films, x = "Revenue(INR)", labels = {'Revenue(INR)' : 'Amount of Money Made(INR)'}, title = "Number of Outliers in Revenue(INR) column of masala films")

# %%
px.box(masala_films, x = "Budget(INR)", labels = {'Budget(INR)' : 'Amount of Money Spend(INR)'}, title = "Number of Outliers in Budget(INR) column of masala films")

# %% [markdown]
# # **EDA of mythological films**

# %%
mythological_films = films[films["Genre"] == "mythological"]
mythological_films
# Out:
#                             Movie Name Release Period Whether Remake  \
# 129          Jai Balaji Mehndipur Wale         Normal             No
# 514           Mahabharat Aur Barbareek         Normal             No
# 605                          Maalik Ek         Normal             No
# 907       Shraddha Shakti Jai Ambe Maa         Normal             No
# 931    Vighnaharta Shree Siddhivinayak         Normal             No
# 942                      Hey Bholenath        Holiday             No
# 1031                 Jai Jagdambey Maa        Holiday             No
# 1056                     Jai Mahalaxmi         Normal             No
# 1087                  Jai Santoshi Maa        Holiday             No
# 1149                Khwaja Mere Khwaja         Normal             No
# 1325                     Jai Jagannath        Holiday             No
# 1445  Beda Paar Karte Bhagwan Amarnath         Normal             No
# 1557         Shrrameya - The Laborious         Normal             No
# ...

# %%
mythological_films.head()
# Out:
#                           Movie Name Release Period Whether Remake  \
# 129        Jai Balaji Mehndipur Wale         Normal             No
# 514         Mahabharat Aur Barbareek         Normal             No
# 605                        Maalik Ek         Normal             No
# 907     Shraddha Shakti Jai Ambe Maa         Normal             No
# 931  Vighnaharta Shree Siddhivinayak         Normal             No
#
#     Whether Franchise         Genre New Actor New Director New Music Director  \
# 129                No  mythological       Yes          Yes                Yes
# 514                No  mythological        No          Yes                 No
# 605                No  mythological        No           No                 No
# 907                No  mythological        No          Yes                Yes
# 931                No  mythological        No          Yes                 No
#
#          Lead Star            Director     Music Director  Number of Screens  \
# ...

# %%
mythological_films.tail()
# Out:
#                             Movie Name Release Period Whether Remake  \
# 1149                Khwaja Mere Khwaja         Normal             No
# 1325                     Jai Jagannath        Holiday             No
# 1445  Beda Paar Karte Bhagwan Amarnath         Normal             No
# 1557         Shrrameya - The Laborious         Normal             No
# 1599                 Jai Narmada Maiya         Normal             No
#
#      Whether Franchise         Genre New Actor New Director  \
# 1149                No  mythological        No          Yes
# 1325                No  mythological       Yes          Yes
# 1445                No  mythological       Yes           No
# 1557                No  mythological        No          Yes
# 1599                No  mythological       Yes          Yes
#
#      New Music Director       Lead Star              Director  \
# 1149                Yes      Raza Murad          Aalima Ahmed
# ...

# %%
mythological_films.shape
# Out:
# (14, 14)

# %%
mythological_films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14 entries, 129 to 1599
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Movie Name          14 non-null     object
#  1   Release Period      14 non-null     object
#  2   Whether Remake      14 non-null     object
#  3   Whether Franchise   14 non-null     object
#  4   Genre               14 non-null     object
#  5   New Actor           14 non-null     object
#  6   New Director        14 non-null     object
#  7   New Music Director  14 non-null     object
#  8   Lead Star           14 non-null     object
#  9   Director            14 non-null     object
#  10  Music Director      14 non-null     object
#  11  Number of Screens   14 non-null     int64
#  12  Revenue(INR)        14 non-null     int64
#  13  Budget(INR)         14 non-null     int64
# dtypes: int64(3), object(11)
# memory usage: 1.6+ KB

# %%
mythological_films.describe()
# Out:
#        Number of Screens  Revenue(INR)   Budget(INR)
# count          14.000000  1.400000e+01  1.400000e+01
# mean           20.428571  9.214286e+06  7.280357e+05
# std            32.486007  1.431475e+07  9.550847e+05
# min             1.000000  1.000000e+06  3.500000e+04
# 25%             3.500000  1.625000e+06  1.225000e+05
# 50%             7.500000  2.250000e+06  3.875000e+05
# 75%            13.750000  8.250000e+06  7.725000e+05
# max           110.000000  4.250000e+07  3.100000e+06

# %%
mythological_films.isnull().sum()
# Out:
# Movie Name            0
# Release Period        0
# Whether Remake        0
# Whether Franchise     0
# Genre                 0
# New Actor             0
# New Director          0
# New Music Director    0
# Lead Star             0
# Director              0
# Music Director        0
# Number of Screens     0
# Revenue(INR)          0
# Budget(INR)           0
# dtype: int64

# %%
mythological_films.duplicated().sum()
# Out:
# 0

# %%
mythological_films.nunique()
# Out:
# Movie Name            14
# Release Period         2
# Whether Remake         1
# Whether Franchise      1
# Genre                  1
# New Actor              2
# New Director           2
# New Music Director     2
# Lead Star             14
# Director              14
# Music Director        13
# Number of Screens      8
# Revenue(INR)           9
# Budget(INR)           13
# dtype: int64

# %%
px.bar(mythological_films.nunique().sort_values(ascending = False),mythological_films.nunique().sort_values(ascending = False), labels = {'x' : 'Number of unique values',
                                                                                                                   'index' : 'Variable Name'},
       title = 'Unique values of each columns in mythological films')

# %%
mythological_films.index
# Out:
# Int64Index([129, 514, 605, 907, 931, 942, 1031, 1056, 1087, 1149, 1325, 1445,
#             1557, 1599],
#            dtype='int64')

# %%
mythological_films.corr()
# Out:
#                    Number of Screens  Revenue(INR)  Budget(INR)
# Number of Screens           1.000000      0.602396     0.682198
# Revenue(INR)                0.602396      1.000000     0.583358
# Budget(INR)                 0.682198      0.583358     1.000000

# %%
sns.heatmap(mythological_films.corr())
# Out:
# <AxesSubplot:>

# %%
px.box(mythological_films, x = "Number of Screens", title = "Number of Outliers in Number of Screens column of mythological films")

# %%
px.box(mythological_films, x = "Revenue(INR)", labels = {'Revenue(INR)' : 'Amount of Money Made(INR)'}, title = "Number of Outliers in Revenue(INR) column of mythological films")

# %%
px.box(mythological_films, x = "Budget(INR)", labels = {'Budget(INR)' : 'Amount of Money Spend(INR)'}, title = "Number of Outliers in Budget(INR) column of mythological films")

# %% [markdown]
# # **EDA of animation films**

# %%
animation_films = films[films["Genre"] == "animation"]
animation_films
# Out:
#                Movie Name Release Period Whether Remake Whether Franchise  \
# 149                 Jumbo        Holiday             No                No
# 664     Main Hoon Krishna        Holiday             No                No
# 1013  My Friend Ganesha 3         Normal             No               Yes
#
#           Genre New Actor New Director New Music Director         Lead Star  \
# 149   animation        No          Yes                 No      Akshay Kumar
# 664   animation        No           No                 No       Juhi Chawla
# 1013  animation       Yes           No                 No  Rahul Pendkalkar
#
#                Director  Music Director  Number of Screens  Revenue(INR)  \
# 149   Kompin Kemgumnird     Ram Sampath                250     210000000
# 664       Rajiv S. Ruia  Amjad - Nadeem                175      50000000
# 1013      Rajiv S. Ruia     Baba Sehgal                 50      32500000
#
#       Budget(INR)
# 149      34700000
# 664       2900000
# ...

# %%
animation_films.head()
# Out:
#                Movie Name Release Period Whether Remake Whether Franchise  \
# 149                 Jumbo        Holiday             No                No
# 664     Main Hoon Krishna        Holiday             No                No
# 1013  My Friend Ganesha 3         Normal             No               Yes
#
#           Genre New Actor New Director New Music Director         Lead Star  \
# 149   animation        No          Yes                 No      Akshay Kumar
# 664   animation        No           No                 No       Juhi Chawla
# 1013  animation       Yes           No                 No  Rahul Pendkalkar
#
#                Director  Music Director  Number of Screens  Revenue(INR)  \
# 149   Kompin Kemgumnird     Ram Sampath                250     210000000
# 664       Rajiv S. Ruia  Amjad - Nadeem                175      50000000
# 1013      Rajiv S. Ruia     Baba Sehgal                 50      32500000
#
#       Budget(INR)
# 149      34700000
# 664       2900000
# ...

# %%
animation_films.tail()
# Out:
#                Movie Name Release Period Whether Remake Whether Franchise  \
# 149                 Jumbo        Holiday             No                No
# 664     Main Hoon Krishna        Holiday             No                No
# 1013  My Friend Ganesha 3         Normal             No               Yes
#
#           Genre New Actor New Director New Music Director         Lead Star  \
# 149   animation        No          Yes                 No      Akshay Kumar
# 664   animation        No           No                 No       Juhi Chawla
# 1013  animation       Yes           No                 No  Rahul Pendkalkar
#
#                Director  Music Director  Number of Screens  Revenue(INR)  \
# 149   Kompin Kemgumnird     Ram Sampath                250     210000000
# 664       Rajiv S. Ruia  Amjad - Nadeem                175      50000000
# 1013      Rajiv S. Ruia     Baba Sehgal                 50      32500000
#
#       Budget(INR)
# 149      34700000
# 664       2900000
# ...

# %%
animation_films.shape
# Out:
# (3, 14)

# %%
animation_films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 149 to 1013
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Movie Name          3 non-null      object
#  1   Release Period      3 non-null      object
#  2   Whether Remake      3 non-null      object
#  3   Whether Franchise   3 non-null      object
#  4   Genre               3 non-null      object
#  5   New Actor           3 non-null      object
#  6   New Director        3 non-null      object
#  7   New Music Director  3 non-null      object
#  8   Lead Star           3 non-null      object
#  9   Director            3 non-null      object
#  10  Music Director      3 non-null      object
#  11  Number of Screens   3 non-null      int64
#  12  Revenue(INR)        3 non-null      int64
#  13  Budget(INR)         3 non-null      int64
# dtypes: int64(3), object(11)
# memory usage: 360.0+ bytes

# %%
animation_films.describe()
# Out:
#        Number of Screens  Revenue(INR)   Budget(INR)
# count           3.000000  3.000000e+00  3.000000e+00
# mean          158.333333  9.750000e+07  1.330000e+07
# std           101.036297  9.781999e+07  1.853537e+07
# min            50.000000  3.250000e+07  2.300000e+06
# 25%           112.500000  4.125000e+07  2.600000e+06
# 50%           175.000000  5.000000e+07  2.900000e+06
# 75%           212.500000  1.300000e+08  1.880000e+07
# max           250.000000  2.100000e+08  3.470000e+07

# %%
animation_films.isnull().sum()
# Out:
# Movie Name            0
# Release Period        0
# Whether Remake        0
# Whether Franchise     0
# Genre                 0
# New Actor             0
# New Director          0
# New Music Director    0
# Lead Star             0
# Director              0
# Music Director        0
# Number of Screens     0
# Revenue(INR)          0
# Budget(INR)           0
# dtype: int64

# %%
animation_films.duplicated().sum()
# Out:
# 0

# %%
animation_films.nunique()
# Out:
# Movie Name            3
# Release Period        2
# Whether Remake        1
# Whether Franchise     2
# Genre                 1
# New Actor             2
# New Director          2
# New Music Director    1
# Lead Star             3
# Director              2
# Music Director        3
# Number of Screens     3
# Revenue(INR)          3
# Budget(INR)           3
# dtype: int64

# %%
px.bar(animation_films.nunique().sort_values(ascending = False), animation_films.nunique().sort_values(ascending = False), labels = {'x' : 'Number of unique values',
                                                                                                                   'index' : 'Variable Name'},
       title = 'Unique values of each columns in animation films')

# %%
animation_films.index
# Out:
# Int64Index([149, 664, 1013], dtype='int64')

# %%
animation_films.corr()
# Out:
#                    Number of Screens  Revenue(INR)  Budget(INR)
# Number of Screens           1.000000      0.837897     0.795623
# Revenue(INR)                0.837897      1.000000     0.997309
# Budget(INR)                 0.795623      0.997309     1.000000

# %%
sns.heatmap(animation_films.corr())
# Out:
# <AxesSubplot:>

# %%
px.box(animation_films, x = "Number of Screens", title = "Number of Outliers in Number of Screens column of animation films")

# %%
px.box(animation_films, x = "Revenue(INR)", labels = {'Revenue(INR)' : 'Amount of Money Made(INR)'}, title = "Number of Outliers in Revenue(INR) column of animation films")

# %%
px.box(animation_films, x = "Budget(INR)", labels = {'Budget(INR)' : 'Amount of Money Spend(INR)'}, title = "Number of Outliers in Budget(INR) column of animation films")

# %% [markdown]
# # **EDA of documentary films**

# %%
documentary_films = films[films["Genre"] == "documentary"]
documentary_films
# Out:
#                     Movie Name Release Period Whether Remake  \
# 992  Sachin - A Billion Dreams         Normal             No
#
#     Whether Franchise        Genre New Actor New Director New Music Director  \
# 992                No  documentary       Yes          Yes                 No
#
#             Lead Star       Director Music Director  Number of Screens  \
# 992  Sachin Tendulkar  James Erskine    A.R. Rehman               1950
#
#      Revenue(INR)  Budget(INR)
# 992     390000000    649515000

# %%
documentary_films.head()
# Out:
#                     Movie Name Release Period Whether Remake  \
# 992  Sachin - A Billion Dreams         Normal             No
#
#     Whether Franchise        Genre New Actor New Director New Music Director  \
# 992                No  documentary       Yes          Yes                 No
#
#             Lead Star       Director Music Director  Number of Screens  \
# 992  Sachin Tendulkar  James Erskine    A.R. Rehman               1950
#
#      Revenue(INR)  Budget(INR)
# 992     390000000    649515000

# %%
documentary_films.tail()
# Out:
#                     Movie Name Release Period Whether Remake  \
# 992  Sachin - A Billion Dreams         Normal             No
#
#     Whether Franchise        Genre New Actor New Director New Music Director  \
# 992                No  documentary       Yes          Yes                 No
#
#             Lead Star       Director Music Director  Number of Screens  \
# 992  Sachin Tendulkar  James Erskine    A.R. Rehman               1950
#
#      Revenue(INR)  Budget(INR)
# 992     390000000    649515000

# %%
documentary_films.shape
# Out:
# (1, 14)

# %%
documentary_films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 992 to 992
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Movie Name          1 non-null      object
#  1   Release Period      1 non-null      object
#  2   Whether Remake      1 non-null      object
#  3   Whether Franchise   1 non-null      object
#  4   Genre               1 non-null      object
#  5   New Actor           1 non-null      object
#  6   New Director        1 non-null      object
#  7   New Music Director  1 non-null      object
#  8   Lead Star           1 non-null      object
#  9   Director            1 non-null      object
#  10  Music Director      1 non-null      object
#  11  Number of Screens   1 non-null      int64
#  12  Revenue(INR)        1 non-null      int64
#  13  Budget(INR)         1 non-null      int64
# dtypes: int64(3), object(11)
# memory usage: 120.0+ bytes

# %%
documentary_films.describe()
# Out:
#        Number of Screens  Revenue(INR)  Budget(INR)
# count                1.0           1.0          1.0
# mean              1950.0   390000000.0  649515000.0
# std                  NaN           NaN          NaN
# min               1950.0   390000000.0  649515000.0
# 25%               1950.0   390000000.0  649515000.0
# 50%               1950.0   390000000.0  649515000.0
# 75%               1950.0   390000000.0  649515000.0
# max               1950.0   390000000.0  649515000.0

# %%
documentary_films.isnull().sum()
# Out:
# Movie Name            0
# Release Period        0
# Whether Remake        0
# Whether Franchise     0
# Genre                 0
# New Actor             0
# New Director          0
# New Music Director    0
# Lead Star             0
# Director              0
# Music Director        0
# Number of Screens     0
# Revenue(INR)          0
# Budget(INR)           0
# dtype: int64

# %%
documentary_films.duplicated().sum()
# Out:
# 0

# %%
documentary_films.nunique()
# Out:
# Movie Name            1
# Release Period        1
# Whether Remake        1
# Whether Franchise     1
# Genre                 1
# New Actor             1
# New Director          1
# New Music Director    1
# Lead Star             1
# Director              1
# Music Director        1
# Number of Screens     1
# Revenue(INR)          1
# Budget(INR)           1
# dtype: int64

# %%
px.bar(documentary_films.nunique().sort_values(ascending = False), documentary_films.nunique().sort_values(ascending = False), labels = {'x' : 'Number of unique values',
                                                                                                                   'index' : 'Variable Name'},
       title = 'Unique values of each columns in documentary films')

# %%
documentary_films.index
# Out:
# Int64Index([992], dtype='int64')

# %%
documentary_films.corr()
# Out:
#                    Number of Screens  Revenue(INR)  Budget(INR)
# Number of Screens                NaN           NaN          NaN
# Revenue(INR)                     NaN           NaN          NaN
# Budget(INR)                      NaN           NaN          NaN

# %%
sns.heatmap(documentary_films.corr())
# Out:
# c:\Anaconda\lib\site-packages\seaborn\matrix.py:198: RuntimeWarning:
#
# All-NaN slice encountered
#
# c:\Anaconda\lib\site-packages\seaborn\matrix.py:203: RuntimeWarning:
#
# All-NaN slice encountered
# <AxesSubplot:>

# %%
px.box(documentary_films, x = "Number of Screens", title = "Number of Outliers in Number of Screens column of documentary films")

# %%
px.box(documentary_films, x = "Revenue(INR)", labels = {'Revenue(INR)' : 'Amount of Money Made(INR)'}, title = "Number of Outliers in Revenue(INR) column of documentary films")

# %%
px.box(documentary_films, x = "Budget(INR)", labels = {'Budget(INR)' : 'Amount of Money Spend(INR)'}, title = "Number of Outliers in Budget(INR) column of documentary films")
